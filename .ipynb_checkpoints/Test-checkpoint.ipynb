# %%
import requests
import re
import nltk
from bs4 import BeautifulSoup
from konlpy.tag import Okt
from konlpy.tag import Mecab

# %%
okt = Okt()
mecab = Mecab()

# %%
def parseText (txt):
    regexStr = r'(\(|\[)[^\)^\]]*(\]|\))'
    return list(
        map(lambda s: s.strip(),
            filter(lambda s: len(s) > 0,
                   re.sub(regexStr, ' ', txt).split('.')
                  )
           )
    )

# %%
def printItems (items):
    for item in items:
        print(item)

# %%
def crawler (url): 
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    select = soup.select('.wiki-heading-content > .wiki-paragraph')
    select_list = soup.select('.wiki-heading-content > .wiki-list')
    mbti_name = url[-4:]
    
    result = []

    for paragraph in select:
        if (len(paragraph.text) > 0):
            items = parseText(paragraph.text)
            for item in items:
                result.append(item)
        
    for paragraph in select_list:
        if (len(paragraph.text) > 0):
            items = parseText(paragraph.text)
            for item in items:
                result.append(item)

    return mbti_name, result

# %%
mbti_list = ['ISTJ', 'ISFJ', 'INFJ', 'INTJ', 'ISTP', 'ISFP', 'INFP', 'INTP', 'ESTP', 'ESFP', 'ENFP', 'ENTP', 'ESTJ', 'ESFJ', 'ENFJ', 'ENTJ']

# %%
len(mbti_list)
# Out:
# 16

# %%
data = dict()

# %%
for mbti in mbti_list:
    print('start crawling ' + mbti)
    url = 'https://namu.wiki/w/' + mbti
    _, result = crawler(url)
    data[mbti] = result
# Out:
# start crawling ISTJ
# start crawling ISFJ
# start crawling INFJ
# start crawling INTJ
# start crawling ISTP
# start crawling ISFP
# start crawling INFP
# start crawling INTP
# start crawling ESTP
# start crawling ESFP
# start crawling ENFP
# start crawling ENTP
# start crawling ESTJ
# start crawling ESFJ
# start crawling ENFJ
# start crawling ENTJ

# %%
data
# Out:
# {'ISTJ': ['MBTI와 16Personalities 성격 유형 중 ISTJ 유형을 설명하는 문서',
#   '청렴결백한 논리주의자, 세상의 소금형',
#   '신중하고 조용하며 집중력이 강하고 매사에 철저하며 사리분별력이 뛰어나다',
#   '실제 사실에 대하여 정확하고 체계적으로 기억하며 일 처리에 있어서도 신중하며 책임감이 강하다',
#   '집중력이 강한 현실감각을 지녔으며 조직적이고 침착하다',
#   '보수적인 경향이 있으며, 문제를 해결하는데 과거의 경험을 잘 적용하며, 반복되는 일상적인 일에 대한 인내력이 강하다',
#   '자신과 타인의 감정과 기분을 배려하며, 전체적이고 타협적 방안을 고려하는 노력이 때로 필요하다',
#   '정확성과 조직력을 발휘하는 분야의 일을 선호한다',
#   '겉보기 특성 - 내향적이어서 말을 조금은 아끼는 편이지만 틀에 짜여진 사회에서 주어진 임무를 매우 철저하게 완수하고 규칙을 잘 준수하는 유형이라 회사나 공공기관에서 일반적으로 가장 선호되는 성격 유형 중에 하나다',
#   '학교에서 역시 선생님들이 일반적으로 가장 좋아하는 성격의 학생들 중에 하나',
#   '자기관리 능력에서 최강으로 주제넘는 말이나 행동을 할 가능성이 가장 낮은 유형이기도 하다',
#   '특히 겉으로 튀는 것을 별로 안좋아하고 용의 단정하며 가장 정돈된 스타일의 대표주자이며, 우리나라 치과의사들 중 이 성격 유형이 가장 많이 나타나는 걸로 유명하다',
#   'MBTI 유형 중 가장 흔하며 , 여성보다는 남성에게서 흔하다',
#   '주의 - 아래 항목은 다른 사람이 각 유형들을 보았을 때 일반적으로 느끼는 특성 위주로 서술되어 있다는 점을 감안할 것',
#   '대한민국 부모들의 성격 유형 중 가장 많다',
#   'ISTJ 어른들과 비슷하다',
#   '사춘기 시절 방황하는 몇 년 정도를 제외하면 빼어난 노력파적인 모습과 책임감, 자제력, 자기관리 모습을 보여준다',
#   '따라서 일반적인 학교 선생님들도 매우 좋아한다',
#   '열심히 공부를 해서 최소 중상위권 수준의 성적을 발휘하는 경우가 많다',
#   '자녀가 SJ성향이 아닌 경우 자녀의 곧이곧대로 성격으로 부모님이 조금 어려워하는 경우도 있다',
#   '오래된 조직을 좋아한다',
#   '부하 직원을 부모와 자녀 관계같이 돌보려고 한다',
#   '선입견이 강하다',
#   '친숙하지 않은 장소에 나서기를 주저한다',
#   '지나고 난 다음에 따지는 편이다',
#   '주어진 업무나 책임을 끝까지 완수한다',
#   '우리나라에서는 장남 같다, 장녀 같다 라는 소리를 잘 듣는다',
#   '변화에 적응이 더디다',
#   '원리 원칙적이다',
#   '교통체증을 미리 계산해서 약속시간을 지킨다',
#   '이유없이 돌아다니지 않는다',
#   '대인관계 폭이 자꾸 좁아지고 대신 할 일이 늘어 난다',
#   '실수한 것을 참지 못하고 즉각 수정하기를 원한다',
#   '남들이 속을 모른다라고 말한다',
#   '틀에 박힌 규칙적인 일을 좋아한다',
#   '휴일에도 집에서 주로 지낸다',
#   '참고 참았다가 확 터뜨리는 편이다',
#   '논리적, 합리적이지 않으면 인정하지 않는다',
#   '웃음이 적다',
#   '반대 성향을 지닌 사람과 처음에는 원만히 지내나 결국 멀어진다',
#   '잘못했다는 건 인정하면서도 미안하다, 잘못했다라고 잘 못한다',
#   '정리정돈을 해 놓는 것이 우선이다',
#   '직설적인 표현을 많이 하는 편이다',
#   '거의 모든 종류의 공무원 사무직, 회사원, 회계관련 직종에서 최고의 실력을 발휘한다',
#   '정해진 일을 형식대로 치밀하게 처리하는 면에서는 이들을 따라올 자가 없다',
#   '현실성, 대중성을 중시하므로 취미를 가져도 일반적인 것, 아니면 전통적인 것을 많이 선호한다',
#   '통제적인 군대나 단체 생활에도 매우 잘 적응한다',
#   '휴대폰 연락처는 별명보다는   이름 석 자만 적는 것을 선호한다',
#   '여행을 떠날 때는 교통편과 숙박, 관광지, 식당, 예산 등 일정을 사전에 철두철미하게 계획한다',
#   '갈등을 표면화 하기보다는 가급적 뒤에서 조용히 해결한다',
#   '겉보기에 차가워 보인다는 소리를 종종 듣는다',
#   '모든 종류의 공무원군인•경찰 치과의사',
#   '대한민국 특유의 과묵한 가부장적인 아버지, 장녀같은 어머니상이다',
#   '근면, 성실, 열렬한 노력파적인 모습과 강한 책임감을 보이며 자녀들도 가급적이면 그렇게 되기를 바란다',
#   '연세가 들면서 회사에서 승진을 잘 하고 경제적으로도 안정된 삶을 산다',
#   '자영업을 하는 경우는 드물다',
#   '보수적이며 전통적인 가치관을 중시한다',
#   '자녀가 성격이 특이하거나, 게으르거나, 너무 놀기 좋아하거나, 덕후 기질이 있거나 할 경우 걱정을 많이 한다',
#   '자녀가 명문대학을 입학, 졸업하거나, 좋은 직장에 취업을 하는 등 현실적인 목표를 이루었을 경우 겉으로는 표현을 잘 안 해도 속으로는 매우 뿌듯해한다',
#   'ISTJ 마이너 갤러리',
#   '차태현 출처안소희 출처 김성규  출처남윤수 출처마크  출처선율    출처이원석  출처이은상 출처정찬우  출처찬미  출처혁  출처BC  출처우왁굳 출처윤도영  출처츄정 출처PewDiePie 출처자까의 어머니 출처성훈  출처제이크  출처'],
#  'ISFJ': ['MBTI와 16Personalities 성격 유형 중 ISFJ 유형을 설명하는 문서',
#   '용감한 수호자형, 임금 뒤편의 권력형, 게으른 완벽주의자형, 배려왕 서포터형ISFJ 유형 성격의 소유자는 조용하고 차분하며 온정적이고 친근하다',
#   '책임감과 인내력 또한 강하다',
#   '본인이 존경하거나 좋아하는 사람에 대해서는 충성심과 애정이 가득하다',
#   '이들은 언제나 진솔하려 노력하고 가볍지 않기 때문에 관계를 맺기에 가장 믿음직스러운 유형이다',
#   '내향형 성격 중에서는 외향성이 가장 강하다',
#   '감정을 파악하는 데는 능숙하지만 표현하는 데는 서툴기 때문에 관계에 있어 항상 걱정을 한다',
#   '업무에 있어서는 현실 감각을 가지고 실제적이고 계획적이며 협조적으로 일을 처리한다',
#   '완벽한 결과물을 도출하지 못할 경우 상당한 스트레스를 받으며, 이상과 달리 게으른 자신에게서도 극심한 괴리감을 느낀다',
#   '경험을 통해서 자신이 틀렸다고 인정할 때까지 꾸준히 밀고 나가는 편이다',
#   '때때로 독창성과 자신을 명확하게 표현하는 능력이 필요할 때가 있다',
#   '한국에서는 MBTI 유형 중 ISTJ, ESTJ, ISTP 다음으로 흔한 편이나 성격으로 정의내리기 가장 어려운 유형이다',
#   '세상이 더 나은 방향으로 굴러가기 위해서는, 이들의 올곧음과 다정함이 필수적이다',
#   '눈치가 상당히 빠르기 때문에 상대의 성향과 분위기를 파악하고 그에 맞는 가면을 쓸 수 있다',
#   '공감 능력이 뛰어나다',
#   '눈물도 많지만 남들 앞에서 잘 보이지는 않는다',
#   '솔직하고 빈말을 못한다',
#   '싸움 등의 갈등 상황을 불편해하며, 그런 상황을 마주하면 스트레스를 많이 받는다',
#   '약속을 매우 중요하게 여긴다',
#   '집에서 나가는 것을 몹시 귀찮아하지만 막상 나가면 잘 논다',
#   '개인 시간 방해 받는 것을 싫어한다',
#   '끈기 있고 성실하며 안정감이 있다',
#   '꼼꼼하고 섬세하다',
#   '치밀성과 반복을 요하는 일을 끝까지 해나가는 인내력이 있다',
#   '안정과 평온을 중시하여 모험이나 변화를 즐기지 않는다',
#   '자아성찰을 꽤 냉정하게 하여 타인에게보다 본인 스스로에게 더 엄격하다',
#   '정해진 틀을 깨는 것을 망설인다',
#   '돈, 시간, 감정 등의 낭비를 싫어한다',
#   '어떤 사람이 외적으로 이상형이어도 인성에 문제가 있다면 바로 정이 떨어진다',
#   '주목 공포증, 발표 공포증이 있는 경우가 많다',
#   '자기 의견을 끝까지 주장하지 못하고 다수 의견에 따르게 된다',
#   '주관이 확고한 것에 비해 자기주장을 잘 못하여 자책한다',
#   '남에게 싫은 소리를 잘 못하며 싫은 소리를 들은 경우엔 티는 안 내지만 속상해 하고 곱씹는다',
#   '다수보다 소수로 구성된 단체 활동을 선호한다',
#   '낯선 것을 불편해하며 어느 정도의 적응 기간이 필요하다',
#   '대비가 철저하여 여행 시 짐이 많다',
#   '본인이 어디에든 도움이 되는 것을 좋아한다',
#   '타인의 의견이나 말을 귀담아 듣는다',
#   '배려 없이 직설적인 말투, 무례한 언동을 굉장히 싫어한다',
#   'ISFJ를 상대할 때 이 부분은 주의할 필요가 있다',
#   '오만, 거만, 자만, 허세를 싫어한다',
#   '감정에 자주 지배당하곤 하는데 이때마저도 표현을 잘 안하기 때문에 속병이 엄청나지만 겉보기에는 감정 조절에 능숙해 보인다',
#   '평균적으로 상처는 더 잘 받지만 그에 대한 표출은 더 못하기 때문이다',
#   '참고 참았다가 터뜨리는 편이다',
#   '파격적인 것을 선호하지 않는다',
#   '어른들이 좋아하나 본인은 힘들다',
#   '아는 범위 내에선 눈치가 매우 빠르지만 나서는 것을 좋아하지 않아 꼭 필요한 경우가 아니라면 일부러 모르는 척을 하는 경우가 많다',
#   '한번 마음을 연 상대에겐 다정하고 헌신적으로 대하지만 상대가 이것을 이용하거나 당연하게 여기면 냉정해진다',
#   '부적절한 단어 사용 한 번으로 그 사람에 대한 평가가 바닥까지 추락할 수 있다',
#   '기본적으로 정이 많지만 남용하지는 않는다',
#   '부탁하거나 신세 지는 것을 어려워한다',
#   '독립적이며 생활력이 강하다',
#   '쾌락주의와 먼 성격 중 하나이다',
#   '느끼고 생각하는 것에 비해 표현이 적다',
#   '본인이 좋아하는 사람들에겐 표현을 많이 하려고 노력하지만 상대는 알아채지 못하는 경우가 자주 있다',
#   '타인이 모종의 언행이나 행동으로 이들의 선을 넘으면, 손절하거나 무시하는 등 없는사람 취급하는데, ISFJ 성격상 직접적으로 표현하지 않기 때문에 당사자는 알기 어렵다',
#   '권위를 존중하고 윗사람에게 예의 바르지만 상대방이 공익을 저해하거나 너무나 권위적인 태도를 보일 경우 반항적인 모습을 보이기도 한다',
#   '자식에 대한 애정이 각별한 부모가 되기도 한다',
#   '',
#   'ISFJ 마이너 갤러리',
#   '최강창민 출처태연 정채연  출처다현  출처정연  출처신비  출처비니  출처 루다  출처 도영  출처재민  정한  출처지수연  출처다미  출처 예지  출처소희  출처다현  출처수윤  출처양예나  출처김채원  출처영재 , 진영  출처셔누  출처이민혁  이서연  출처이우진 이진우 백지헌  출처야부키 나코  한승우 , 강승식  출처JR  차훈  출처규진  출처김동현  출처온다  유  출처김요한  출처앨런  출처차준호  출처 김종민  출처 신지  출처나르샤  출처나플라 출처이석원 출처한승연 출처안영미 출처장도연 출처얏따 출처삼식  출처피글로그  출처노랭이  출처자까  출처 이진우  출처유채  출처'],
#  'INFJ': ['MBTI와 16Personalities 성격 유형 중 INFJ 유형을 설명하는 문서',
#   '선의의 옹호자예언자 유형',
#   '인내심이 많고 통찰력과 직관력이 뛰어나며 양심이 바르고 화합을 추구한다',
#   '창의력이 뛰어나며, 강한 직관력으로 말없이 타인에게 영향력을 끼친다',
#   '독창성과 내적 독립심이 강하며, 확고한 신념과 열정으로 자신의 영감을 구현시켜 나가는 정신적 지도자들이 많다',
#   '한 곳에 몰두하는 경향으로 목적 달성에 필요한 주변적인 조건들을 경시하기 쉽고, 자기 안의 갈등이 많고 복잡하다',
#   '이들은 풍부한 내적인 생활을 소유하고 있다',
#   '겉보기 특성 - INTP, INFP, INTJ처럼 내향적인 이상주의자 성격을 가지고 있다',
#   '따라서 일반적으로 현실적인 장소에서는 말이 없어 보이기도 쉽다',
#   '친한 친구나 지인 앞에서 미래에 대한 각종 예측과 상상에 대한 말을 하기 좋아하는 특성이 있다',
#   '',
#   '주의 - 아래 항목은 다른 사람이 각 유형들을 보았을 때 일반적으로 느끼는 특성 위주로 서술되어 있다는 점을 감안할 것',
#   '다음은 INFJ에 관해 다루는 국내 커뮤니티들의 목록이다',
#   '',
#   '가장 흔치 않은 성격 유형으로 전 세계 인구의 채 1%도 되지 않는다',
#   '영감력이 뛰어나고 깊은 통찰력이 있다',
#   '특유의 페르소나를 사용해 타인에게 잘 맞춰주는 대표적인 유형이며 언쟁과 싸움을 조정하고자 한다',
#   '평소에는 온화하지만 자신의 신념에 어긋나는 일이나 인내심의 한계를 넘을 경우엔 불같이 화를 낼 수 있다',
#   '거기다 한번 화가 나면 스스로를 제어하기 힘들기도 하다',
#   "'사람'에 대한 관심이 많다",
#   '자신의 감정을 겉으로 잘 드러내지 않기 때문에 무뚝뚝하거나 차가워 보일 수 있다',
#   '의미 없다고 느끼는 일에 "?" 가 따른다',
#   '또한 어떤 일에 의미부여하는 것을 좋아한다',
#   '겉으로 티 내지 않으나 완벽주의가 강하다',
#   '분쟁과 다툼을 싫어하며 피하고자 한다',
#   '이상적이고 창조적이나 동시에 염세적이다',
#   '타인에게 도움을 주는 것에 기뻐하지만, 상처를 크게 받을 경우 가장 냉정하게 인간관계를 정리한다',
#   '특유의 깊고 따뜻한 속마음과 순수함이 있다',
#   '다만 겉으로 쉽게 잘 드러내지 않을 뿐이다',
#   '거짓말을 날카롭게 간파한다',
#   '하지만 분위기상 모른 척하거나 눈감아 주는 게 대부분이다',
#   '생각이 많아 현실과 동떨어져 있으며, 이에 적응하기 어렵다',
#   '이때문에 간단한 일을 실수할 때가 있다',
#   '눈치가 빠르기 때문에 상대의 감정을 잘 파악한다',
#   '상대의 장점을 굉장히 잘 알아낸다',
#   '동시에 단점 또한 잘 알아낸다',
#   '같은 나이에 비해서 조숙해 보인다',
#   '어른스럽다는 말을 많이 듣는 편이다',
#   '때론 애늙은이 소리를 듣는 경우도 있다',
#   '깨지지 않는 차분한 아우라를 지닌 사람들이 많다',
#   '신비로운 분위기를 내는 대표적인 유형이다',
#   '문제의 본질을 생각한다',
#   '비유와 은유를 잘한다',
#   '본인이 하는 말을 남들이 잘 이해하지 못하는 경우가 있다',
#   '독립심이 강하고 자기주관이 뚜렷하기 때문에 구속 받거나 강요 당하는 것을 아주 싫어한다',
#   '타인의 시선에서 보았을 때, 내향적이면서도 외향적이다',
#   '단, 이러한 인상에 다가가 섣불리 친해지려하면, 호불호가 분명한 성격 특성상 경계할 가능성이 높다',
#   '사람과의 교제 시작이 어렵고,  대체로 집돌이/집순이들이 많다',
#   '필요 시 페르소나를 사용한다',
#   '다른 사람이나 자신에 대해 표면적 성격 속에 내면적 성격이 하나 더 있다고 느낀다',
#   "거짓말을 잘 못하지만 특유의 솔직하고 '모든 것을 말하지 않는' 화법 때문에 페르소나를 잘 쓴다고 말할 수 있다",
#   '일부러 상대방을 속이려는 의도는 아니다',
#   '호불호가 분명하며, ‘불호’라고 생각하는 일이나 사람에게 관심이 없다',
#   '이들의 가장 명확한 목표 중 하나는 다른 사람들을 돕는 것이다',
#   '그들이 발전하고, 진보하며, 자립할 수 있도록 돕는다',
#   '조용히 책 읽는 것을 좋아하는 경우가 많고, 사색을 즐기는 편이다',
#   '자아성찰을 꽤 냉정하게 하여 타인에게보다 본인 스스로에게 더 엄격하다',
#   '주위의 사소한 변화도 금방 알아채고 눈치가 얍삽할 정도로 매우 빠른 편이다',
#   '내성적이고 조용하지만 외향 감정을 활용하여 어느 상황에나 자신을 카멜레온처럼 보호색을 입혀 적당히 적응한다',
#   '상대방에게 상처받거나 거부당하는 것에 대해 민감하다',
#   '상대방의 표정, 억양, 뉘앙스 이러한 것들을 노력 없이도 자연스레 인식이 하여 상대의 의도나 감정을 잘 잡아낸다차분하면서도 감성적이다',
#   '속마음을 잘 드러내지 않는다',
#   '칼 품은 벨벳사람에 대한 통찰력이 높다',
#   '복잡한 의미와 사람들과의 관계를 직관적으로 잘 이해한다',
#   '상대의 감정, 성향을 파악하고, 그 눈높이에 맞춘다',
#   '따라서 만나는 사람에 따라 모습을 달리 한다고 비춰질 수 있다',
#   '이상주의적이며 옳고 그른 것에 대해 높은 수준의 감각을 갖고 있다',
#   '옳다고 확신이 생긴 신념은 끝까지 밀고 나간다',
#   '자신이 세운 기준이나 가치관이 비판당하거나 비난받을 경우 공격적이며 고집스러운 면모를 보이기도 한다',
#   '사람이 가진 가치관과 내면을 중요시 여긴다',
#   '사회적 불의에 민감하며, 예의, 도덕을 굉장히 중요하게 생각한다',
#   '무례한 사람, 비도덕적인 사람, 서로 다름을 인정하지 않거나 타협이 없는 사람, 본인의 철칙에서 벗어난 사람은 칼같이 자르거나 아예 상대하지 않는다',
#   '현실에서도 이상을 꿈꾼다',
#   '거기다 혼자만의 시간을 필요로 하고, 즐긴다',
#   '외로움을 즐기면서도 외로움을 잘 타는 유형 중 하나다',
#   '호기심이 많고 늘 의문을 달고 산다',
#   '질문을 안 할 뿐이지 가슴 속에 묻어둔 질문이 매우 많다',
#   '남에게 민폐 끼치는 걸 몹시 싫어한다',
#   '자신이 갖고 있는 고유한 가치관이 웬만해선 흔들리지 않는다',
#   '공감력이 뛰어나고 반응에 민감하여 유리멘탈로 보일 수 있으나, 남에게 휘둘리는 성향은 아니다',
#   '',
#   '대체로 집안 분위기가 자유로운 편이다',
#   '아이의 의견과 생각을 펼칠 수 있도록 환경을 조성하는 편이다',
#   '성격이 대체로 자유롭거나 편견이 별로 없는 편이다',
#   '여러 가지를 고루 알고 있다',
#   '집에 책이 많다',
#   '그에 따라 아이가 여러 지식을 편히 받아들일 수 있다',
#   '아이와 대화하는 것을 좋아한다',
#   '주제에 구애받지 않고, 아이와 의견을 나눌 수 있는 것이라면 무엇이든 대화 주제가 될 수 있다',
#   '자신이 맡은 분야에서 일정 경지에 도달한 경우가 많다',
#   '아이에게 자신의 지식을 최대한 흡수시키려 노력한다',
#   '아이에게 예의를 가르치는 것이 필수라고 생각한다',
#   '뉴스나 사설에 관심이 많다',
#   '드라마나 영화를 볼 때 고증에 관심이 많다',
#   '자신의 의견을 입으로는 쉽게 전달하지 못한다',
#   '그러나, 문서화했을 때에는 의견이 명확하고 간결하게 전달된다',
#   '여러 가지를 많이 알고 있다',
#   '또한, 주변에서 여러 지식을 흡수하고 싶어하며, 호기심이 많다',
#   '어릴 때부터 "왜?"라는 말을 제일 많이 한다',
#   '다른 사람과 친해지기를 껄끄러워 하는 편이나, 친해지면 자신의 반도 내줄 절친으로 만든다',
#   '주변인들은 눈치채지 못하는 경우도 많으나, 학생 때에 고민이 매우 많다',
#   '진로나 학업 등에 상관없이 고민이 될 수 있는 부분에서는 무엇이든 고민이 생긴다',
#   '대체로 밖에 나가지 않는다',
#   '실내를 훨씬 좋아하며, 약속이 잡히거나 필요하지 않는 이상은 밖에 잘 나가지 않는다',
#   '몽상에 빠지거나, 시나 수필 등의 글쓰기를 좋아한다',
#   '남을 돕는 일에는 묵묵히 도와준다',
#   '학교 생활에서는 대체로 서기나 봉사부 등의 묵묵한 조력자 역할을 수행한다',
#   '자신의 능력을 드러낼 수 있는 것에는 자신을 드러내고자 한다',
#   '자신의 영감과 생각을 드러내려 하기 때문이다',
#   'INFJ디시인사이드 INFJ 갤러리',
#   '추측이 아닌 실제로 검사한 인물만을 기록하며, 출처를 반드시 표기하도록 한다',
#   '태연  출처 솔라  출처전지우  출처지연  출처효민  혜림  출처소진  출처카이  출처 닉쿤  출처JB  출처혜정  장예은  엄지   출처 레오  출처차은우  출처마크  출처지성  텐  출처정우  세이 , 루아 , 리나  출처이브  출처 류수정  출처원우 , 우지 , 디에잇  출처강승윤  원필  출처 효진 제현  출처주창욱  출처강현  출처형준  출처소정환  출처채보훈 출처형섭 렌  케이시 출처희승',
#   '김이나 출처일리야 벨랴코프 출처김수지  출처이재은  출처',
#   '간미연성유리 출처김보라 출처천우희 김새론 정소민 표예진 남다름 출처저스틴 H',
#   '민',
#   '강유미  출처양세형  출처',
#   '애쉬 아일랜드 최삼 출처장문복 출처Skinny Brown',
#   '햄튜브 출처임한올 출처려리 출처꽃핀 출처 솔빈 혜안  출처힙합팬 이창민 출처양아지마인드C  출처슬라정  김뚜띠 출처',
#   '전문 계열: 학자, 전문직, 특정 분야의 전문가 등예술 계열: 시인, 작가, 음악가, 무용수, 배우 등사업 계열: CEO, 기획자, 인사 담당관'],
#  'INTJ': ['용의주도한 전략가과학자형 / 건축가형대부분의 사항에 마땅한 근거를 논해야 하는 합리적 성향이 강하다',
#   '그만큼 논리적 엄밀함을 중시하기 때문에 감성적인 논쟁 상황을 꺼림직해하며 객관성을 우선시한다',
#   '이러한 성향은 토론 상황이 아닌 일반적인 일상 상황에서도 유효하기 때문에 인간관계에서 냉소적으로 비춰지기도 한다',
#   '그럼에도 반대 의견에 관대하다고 알려져 있다',
#   '하지만 그만큼의 기발함과 합리성을 못 얻어내면, 그 상대를 오랫동안 경멸할 수 있다',
#   '직관으로 과감하게 상황을 끌고 나가기 때문에, 구상과 회의에서 놀라운 제안을 펼치는 강점이 있다',
#   '이들의 정보 처리 방식은 ‘나무보다 숲’, ‘가지보다 뿌리’에 비유할 수 있다',
#   '목차와 분류 가 정리되지 않은 상황을 언짢아 하기 때문에 이를 체계적으로 구축하려 한다',
#   '다만, 구축 과정에서 초기 목적의식을 잃고 일탈하는 상황에 자주 처하기도 한다',
#   '또 이들의 ‘완벽주의’ 성향과는 어울리지 않아보이는 ‘저조한 실천력’이 의외의 단점으로 꼽히기도 한다',
#   '※ 당사자가 직접 검사한 결과가 있는 경우만\xa0출처와 함께\xa0기재',
#   '논리적이고 객관적이다',
#   '감성이나 감정에 치우친 사고를 멀리 한다',
#   '이상적일 만큼 이론적이다',
#   '합리적이며 공정성을 중시한다',
#   '지식 축적 사고형보단, 기존에 알고 있던 것들을 다각도로 합성시키는 사고형이다',
#   '발상이 완전히 독창적이기보단 ‘적합했던 경험들’을 재조합하여 만든 ‘우아한 솔루션’에 가깝다',
#   '마치 새로운 발상처럼 보이기도 하지만, 경험적 사고를 은연중에 조합한 것이기 때문에 실제 현장에서도 이들의 직감에 대한 정확도가 다소 높은 편에 속한다',
#   '적중 사례를 자주 접하다 보니 자기 확신이 강해지는 계기가 되기도 한다',
#   '반면에, 오히려 완전 신유형이나 경험하지 못했던 발상에 대해서는 굉장히 취약한 편이다',
#   '효율을 위하여 기초를 닦는 것이, 막연히 시작하는 것보다 나은 가치로 여긴다',
#   '일관성 있게 정돈된 체계를 중시한다',
#   '상하 관계 없이 마구잡이로 나열된 것들의 포함 관계를 살피고, 자신만의 목차를 만들어 정리하려고 한다',
#   '예외 상황이 많은 체계를 싫어한다',
#   '정리되지 않은 여러 가지 얕은 잡상식보다, 하나 하나를 체계적이고 엄밀히 이해하려고 한다',
#   '흔히 ‘나무들보다 숲을 보며 사고하는 관점’으로 비유될 수 있다',
#   '세부 사항 을 무시하고, 큰 목차나 큰 틀부터 이해한 뒤 되돌아와서 처리하려고 한다',
#   '세부 항목들간의 공통점을 찾아 묶어서, 큰 항목으로 거슬러 올라간다',
#   '가끔은 못 말릴 정도로 거슬러 올라가는 탓에 초기 목적을 잃기도 한다',
#   '과거, 현재, 미래에 대한 자기 판단이, 미래지향적 으로 다소 편중되어 있다',
#   '학문 분야에서 환원주의적 관점을 가지게 될 수 있다',
#   '예',
#   '자연과학 , 수학, 논리학, 철학을 우선하는 성향',
#   '예술 분야에서 정통성, 극사실주의적인 성향을 가지게 될 수 있다',
#   '객관적인 정보인지 아닌지 여부를 대개 언어를 갖고 판단하는 경향이 있다',
#   '관심을 끌기 위한 목적으로 자극적으로 쓴 제목에 현혹되지 않는다',
#   "'꿀팁' 등 비표준어가 포함되어 있거나 역대급 드립 등이 많이 사용된 정보는 비전문적이라고 느껴 신뢰도가 크게 하락한다",
#   '사회 현실 감각에 무디다',
#   '편법을 저평가하고 정통성을 굳게 지향한다',
#   '예',
#   '‘취업을 위한 공부’, ‘입시를 위한 공부’에 비판적이며 ‘공부를 위한 공부’가 주가 되는 세상을 꿈꾼다',
#   '이들의 공상은 꽤 이론적이고 합리적이지만, 사회 현실을 바꾸겠다는 이상이 포함되어 있어, 즉 현실적이지가 않고 이상적이다',
#   '조용하고 과묵한 성격이다',
#   '모든 MBTI 유형 중 내향 성향이 INTP와 함께 가장 강한 편이다',
#   '필요 이상으로 어려운 사고 활동을 즐긴다',
#   '일상적 상황에서 실수를 자주 범한다',
#   '예',
#   '어설픈 집안일, 계산 실수, 지도를 잘못 봄, 우둔한 노동 감각, 소지품 분실의외로 단순한 상황에서조차 시간을 잡아먹는 조짐이 팽배하다',
#   '사소한 실수를 공개적으로 지적당하면 쓸데없이 큰 상처 를 받는다고 한다',
#   '사회적인 인간 관계 마저 복잡한 사고 방식을 적용하곤 한다',
#   '자기 능력에 대한 자신감이 매우 높다',
#   '모험에 과감하다',
#   '가끔 무모한 도전을 아무 고민 없이 그대로 밀고 나가는 경향도 있다',
#   '불가능해보이는 일들을 이들은 해낸다',
#   '도박을 하면 이들은 그걸 성공시키는 승부사기질이 있다',
#   '자기가 선택한 분야나 과목에 대한 섭렵을 확신한다',
#   '가끔 자기가 모든 문제를 해결했다고 믿는다',
#   '완벽주의 성향이 강하다',
#   '적당히 넘어가야 신속하게 해결된다는 걸 알면서도 그것을 놓기 싫어한다',
#   '멀리 보면 유익하나 당장 필요하지는 않은 소위‘예쁜 쓰레기’를 모아 바로 앞에 닥친 일을 곧잘 망칠 수도 있다',
#   '지나치게 깊어지면 정리벽 , 수집벽, 호더  증후군 성향이 있을 수 있다',
#   '무엇이든 고효율적인 상태를 만든 뒤에야 비로소 ‘시작’을 한다',
#   '계획 또는 도움닫기 단계에서 긴 시간을 투자한다',
#   '만일 도움닫기 단계를 끝내고 실천만 해낸다면 폭발적인 효율을 방출해내는 유형이다',
#   '계획형보다는 즉흥형이다',
#   '틀에 박힌 일과를 수행하는 것에 지루함을 느끼기 때문에, 실천력은 생각보다 크게 떨어지는 편이다',
#   '‘엄청난 계획’을 만들어 놓더라도 정작 본인이 써먹지를 않는다',
#   '다급해질 때까지 일을 미루게 되는 상황을 자주 접한다',
#   '학업·지능 우수형이며, 학업 방식이 여타 유형들과 크게 차이날 만큼 특이한 양상을 띄는 것으로 알려져 있다',
#   '새로운 학문을 시도할 때면, 일반인 대상의 ‘교양 서적’보다 ‘전공 서적 ’을 선호한다',
#   '‘지식적 심화 학습’보다 ‘기초 회귀형 학습’을 취하는 편이다',
#   '단순 나열식·휘발성 지식보다 ‘수학 능력’과  ‘체화형 학습 능력’ 을 고수하는 편이다',
#   'MBTI 유형 중 대학수학능력시험 성적 평균이 가장 높다',
#   '기타 평균 학업 성적과 GPA 도 16유형 중 1위이며 평균 IQ 도 INTP와 더불어 1위에 해당한다',
#   "INTJ가 기반을 두고 있는 지적 열망은 '단순 지식 수준'보다 '수학 능력 수준'에 가깝다",
#   '경쟁을 좋아하는 편이기 때문에 혼자 공부할수록 효율이 떨어진다는 연구도 있다',
#   '‘과제 수행형’보다 ‘아이디어 제시형’이다',
#   '남이 정해준 방식보다 자신만의 자유로운 방식을 지향한다',
#   '계획과 구상 단계에서 기발하고 효율적인 발상을 발휘한다',
#   '과제를 수행하더라도 자기 아이디어를 발휘할 수 있어야 진척도가 쌓이며, 그렇지 못한 과제에 대해서는 진척도가 낮다',
#   '비상 계획을 생각해둔다',
#   '겉으로 모범적으로 보인다',
#   '비평이 늘 비관적이다',
#   '혼자만의 시간을 선호한다',
#   '정작 가장 가까운 사람들을 이해하는 데 익숙지가 않은 편이다',
#   '친구와 지인의 구별이 명확하다',
#   "친구 관계를 '지속' 단계의 반열에 올리기가 가장 어렵다",
#   '소수의 좋은 사람들만 친구로 두고, 다수의 지인을 피하는 편이 다',
#   '인간 관계에서 연락은 의무가 아니라 선택 사항이라 생각한다',
#   '인생에 뚜렷한 목표가 없는 사람과 친하게 지내려고 하지 않을것이다',
#   '인간 관계에서 인기나 관심은 이들에게 필요한 조건이 아니다',
#   '주변 사람을 신뢰하는 기준은 의리보다 능력이다',
#   '본인의 솔직한 감정 표현 을 창피한 것으로 간주한다',
#   '있는 그대로의 감정을 드러내지 않아 성격 알기가 어렵기로 유명하다',
#   '속으로만 자기 주변 사람들을 몹시 아낀다',
#   '기분 좋은 상태임을 겉으로 잘 표현하지 않아 평소에 비인간적으로 비춰진다',
#   '인간적이기보다 능력적으로 인정받기를 갈망한다',
#   '공부벌레 혹은 책벌레라고 불리지만 본인은 이를 자랑스럽게 생각한다',
#   '내재된 외향성이 부족하므로 외향적인 사람들의 행동 패턴을 베끼는 것에 의존한다',
#   '편한 사람 앞에선 위트 있는 드립이나 풍자를 서슴없이 던져 상대방을 매료시키기도 한다',
#   '그래서 가끔 I가 아닌 E 성향처럼 보일 때도 있다',
#   '상투적이고 뻔한 잡담을 꺼려한다',
#   '가벼운 분위기를 시사해주지 않는 이상 모든 결정을 진지하게 한다',
#   '친구 간의 결정에 있어서도 감정적인 방법보다 합리적인 절차를 종종 따른다',
#   '감수성과 관계 없이 검증된 과학적 원칙, 사실, 이론에 맞게 생각하며, 이때 INTJ들의 냉랭한 면모를 보기 쉽다',
#   '본인이 정서적인 일을 즐기지 않는 만큼, 상대방들도 필요 이상의 어려운 문제 분석을 즐기지 않는다는 걸 알아둘 필요가 있다',
#   '사회적으로 성숙된 INTJ는 자신과 분야가 다른 사람들을 별로 귀찮게 하고 싶어하지 않는다',
#   '사상과 의견 변화에 열려있는 입장이다',
#   '이들에게 지금보다 더 합당한 상황을 제시하고 납득시키면 신념, 약속, 인맥까지 기꺼이 바꿀 것이다',
#   "반대 의견에 감정적이기보단 '일단 듣고 보자'는 쪽이되, 자신을 변화시킬 만큼의 뚜렷한 결과가 없으면 뒤에 가서 코웃음을 치는 타입이고 끝내는 묵살한다",
#   '전공과 분야에 대한 책임의식을 중요시 여긴다',
#   '자기 전공과 분야에 헌신적이다',
#   '자기 전공에 대하여 얕은 지식과 편견으로 잡담 떠는 사람을 싫어하게 된다',
#   '상대방이 전공 분야에 대하여 소개할 때면 ‘그 사람이 해당 분야에 대해 유능한지’를 먼저 헤아리려고 한다',
#   '지적 인 소울 메이트를 찾는다',
#   '같은 가치를 공유하거나 함께 성장할 수 있는 열정적인 친구 관계를 찾으며  이때 강력하고 흥미로운 우정이 성사된다',
#   '그렇지 못한 사람에겐 흥미를 느끼지 못하며 끝내는 인간 관계 목록에서 제거하려고 할 것이다',
#   '자신에게 쌓인 감정이 있으면 토로해주길 바라는 편이며, 그 속에서 감정을 절제하고 어떻게든 합리적인 결론을 끌어내려고 할 것이다',
#   '하지만 불만 표출이 습관적이면, 떼만 쓴다고 간주하여 아예 관계를 끝내버릴 것이다',
#   'INTJ 본인들은 INTJ끼리 사귀어야 잘 맞겠다는 관념에 사로 잡히지만, 오히려 반대되는 특성을 사귀는 게 본인의 성장에 큰 기회를 제공한다고 한다',
#   '특히 ESF○나 E○FP와 함께 하는 것이 성장 지향에 도움이 된다고 한다',
#   '자신과 다른 통찰력을 가진 사람을 사귀는 것이 더 이득이다',
#   '사랑보다는 우정 관계에서 성공하기 쉽다',
#   '그러나 의외로 여러 유형에 걸쳐 연애 상대로 인기가 많다 조사되었다',
#   '본인들 생각보다 주변에 호감을 가진 사람들이 많을 가능성이 높다',
#   '# 지나치게 분석하고 조목조목 따지려는 성격 탓에 연인 관계를 피곤하게 만든다',
#   '연애로 자주 낙담할 일이 생기면 사랑에 대한 탐색 자체를 포기하기도 한다',
#   '연애를 융통성 있게 접근한다',
#   '이는 상대에 따라 약일 수도, 독일 수도 있다고 한다',
#   '어쩌면 연애를 책으로 배울 수도 있다',
#   '애인을 찾을 때는 자기만의 특정  기준을 충족하는지 따져보려 하고, 데이트 단계에서 벌어질 시나리오들을 미리 계획하고 철저히 완료시키고 싶어한다',
#   '엄격해보이는 첫인상과 달리 친구로 지내기엔 유익하고 편안한 유형이다',
#   '불편한 인간 관계를 개선하고자 뭔가를 바꾸기 시작하면, 그만큼 원상복귀될 가능성도 다른 성격 유형보다 높은 편이어서 오히려 상황을 더 악화시킬 수 있다고 한다',
#   '독립적이며 공동체 의식이 낮다',
#   '‘전체의 책임’을 이해할 수 없어하며, ‘개인의 책임’을 따진다',
#   '‘자기가 속한 단체’와 ‘단체 속의 나’ 자신을 별개라고 생각한다',
#   '자신이 소속된 공동체 속 사람들이라한들 무턱대고 두둔하거나 옹호해주지 않는다',
#   '외로움을 잘 타지 않아 고립을 두려워하지 않는다',
#   '합리적이지 못한 사회 관행을 멍청한 것으로 본다',
#   '무언의 합의 에 대하여 ‘왜 그래야 하는지’ 검토를 다 끝맞추어야 직성이 풀리는 성격이다',
#   '더 효율적이고 합리적인 행동 양식이 있으면, 경로의존성을 깨서라도 그것을 취해야 된다고 생각한다',
#   '',
#   '사회적 합의를 깼을 때 생기는 ‘사회적 비난’을 별로 두려워하지 않는다',
#   '더 넓은 범위의 공익을 지켰다고 믿기 때문이다',
#   "사회적 관습에 거침없는 의견을 자주 피력하는 편이라 불특정 다수에게 '피해야 할 사람'으로 낙인되어 훌륭한 아이디어를 제시해도 무시당하곤 한다",
#   '소규모 팀을 꾸려 일하는 것을 좋아한다',
#   '의외로 팀에서 리더가 되는 경우가 많다',
#   '행동대장 이미지가 아니라 조용하게 지시하고 조언해주는 리더에 가깝다',
#   '분위기파 담당, 발표 담당을 따로 두는 등 다른 사람들의 강점을 살펴보고 적극적으로 이용하는 편이다',
#   '봐주는 스타일은 결코 아니며, 어쩔 수 없는 상황이 와도 따끔한 일침을 던지는 뒤끝이 있다',
#   '팀 워크에서 도움이 떨어지는 동료는 데려올 필요가 없다고 생각한다',
#   '능력 없는 사람한텐 독재자 기질이 있으며, 유능한 사람에겐 그 누구보다도 엄청난 서포터 역할을 해준다',
#   '난기류 속에서 자기 외 팀원들이 모두 격추당하고 있을 때  냉소적으로 돌변하거나 혼자만의 지적  우월성을 드러내기 쉽다',
#   '사회적 결정에 ‘안정성’이 있다기보다는 다소 ‘모험’을 하려는 성격이 짙다',
#   '“여태껏 그래왔는데 바꾸자고?”로 반박하면 이들은 전투적인 논객으로 돌변한다',
#   '누군가 현실적인 타협을 제의해온다면, 한 귀로 듣고 한 귀로 흘리는 편이다',
#   '가끔은 ‘오만하다’ 싶을 정도로 상대방의 권위를 맹신하지 않는 모습을 보인다',
#   '상대방이 사회적 권위 · 학위가 있어도, 논리적 흠결을 보인다거나 객관적이지 않은 모습을 보이면   신용도가 급락한다',
#   '명성과 자리 에 걸맞지 않는다는 확신이 서게 되면, 예우와 연륜을 막론하고 존중해주지 않는다',
#   '사람들이 각자 능력에 맞는 올바른 직책을 가져야 한다고 생각한다',
#   '특혜나 쉬운 방법으로 자리를 차지하는 사람을 부정적으로 바라본다',
#   '명성에 비해 매번 가벼운 성과를 내는 사람의 실체를 어떻게든 폭로할 방법을 찾아내려고 한다',
#   '예민한 이슈에 대해서는 ‘전문가의 단순 의견’보다 ‘전문적 사실’을 더 중시한다',
#   '윗사람에게 굽신거리며 아첨하는 것을 좋아하지 않는다',
#   '자신의 출세를 위해 특정 편에 붙어 줄 서는 사람을 달갑지 않게 본다',
#   'INTJ 쪽이 상사일 경우, 서로 조언해주고 비판해줄 수 있는 양방향 관계 의 부하를 선호한다',
#   '그저 상사에게 점수 따려는 부하에겐 별로 관심이 없다',
#   'INTJ 쪽이 하사일 경우, 상사를 오게 만든다',
#   '자신의 역량을 보여줄 분위기를 필요로 한다',
#   '경쟁을 좋아하며, 가시적인 라이벌이 있어야 발전 속도가 높은 편이다',
#   '자기 의견이 세상 속 여론과 안 맞는 경우가 잦다',
#   '반대 여론이 크다한들, 합리적 질서를 위하여 그것들을 과감히 묵살할 용기가 있다',
#   '이들에게 적합한 리더는 작업 스타일을 이해하고 비전을 발전시키는 데 도움을 줄 수 있어야 한다',
#   '반지성주의를 싫어하며 사람은 누구나 똑똑해질 권리가 있다고 생각한다',
#   '모든 사람이 지적 으로 고등해질 필요가 있다고 생각한다',
#   '지식 전달에 있어 배타적이지 않다',
#   '거래 혹은 업무적인 상황에서, 다른 사람들을 오게 하는 것이 최선의 전략이라고 생각한다',
#   '모든 사람이 독립과 자유를 누리도록 격려한다',
#   '솜씨 발휘와 능력적인 그룹에서 진 빠지게 일하는 것을 좋아한다',
#   '프로젝트 관리자, 시스템 엔지니어, 마케팅 전략가, 시스템 분석가, 군사 전략가로서 저명한 영향력을 행사한다',
#   '직업 적합성을 떠나 능력치가 광범위하여 여러 조직에 영향력을 행사할 수 있다',
#   '자녀에게 최고의 교사이며 본인도 이를 알고 있다',
#   '자녀를 어떻게든 자기가 원하는 이미지 로 만들어내도록 할 것이다',
#   '부모와 자녀가 상호 존중하는 규칙을 개발하고, 책임 교육을 중시한다',
#   '특정 사물이나 생각들을 어린이에게 친화적인 것으로 바꾸려고 노력할 필요가 있다',
#   '애정을 나타내는 경향이 없으므로 이들의 자녀에겐 누구보다 신체적인 애정 표현이 요구된다',
#   '논리 교육을 중시하지만, 정작 아이들의 발달 시기에 둔감한 편이기도 하다',
#   '적절하지 못한 나이대에 특정 교육을 시도하는 건 아닌지 생각해볼 필요가 있다',
#   '유아기인 자녀에게 문제의 해답을 바로 제시하기보단 스스로 탐구하고 해결할 수 있을 때까지 놔두는 편이다',
#   '자녀가 해답을 찾지 못하거나 허구와 지나친 망상에 빠질 경우 이를 시정하려고 들 것이다',
#   '결국은 진리가 상상보다 낫다고 가르치려 할 것이다',
#   '일부러 모험을 많이 시키는 편이다',
#   '어차피 자기 교육을 받았으니 큰 일탈을 저지르지 않을 것이라고 자신하기 때문이다',
#   '자녀가 청소년기일 때 INTJ의 교육 방식은 가장 강력하다',
#   '자녀에게 명확한 답변과 명확한 진로를 제시해주는 등 큰 역할을 한다',
#   '하지만 정서적인 문제까지 그런 식으로 할 경우 자녀가 위험해질 가능성이 높다고 한다',
#   '자녀가 어려운 상황에 빠져도 무턱대고 보호하지 않는다',
#   '육아 접근을 성공적으로 마치고 자녀가 성인기에 접어들면 부모를 신뢰하고 존중할 가능성이 높다',
#   '세계 인구의 2%를 차지하는 희귀 유형이다',
#   '국가별로 국민정서가 다르므로 비율 차이가 있지만  어느 나라에서나 MBTI 인구비율 순위의 최하위권에 속한다',
#   '한국인 중에서는 1',
#   '8~2% 정도로, ENFJ 다음으로 희귀하다',
#   '여성은 0',
#   '8%로 여성 중에서는 가장 적은 유형이다',
#   '현실에서는 보기 힘든 유형이지만 인터넷에서는 가장 흔하게 접할 수 있다',
#   '실질 인구 비율은 최하위권에 속하지만, 그 조건부를 Reddit, Quora 등 Q&A형 커뮤니티 나 위키위키 같은 정보 교류 커뮤니티로 한정시키면 단연 1위이며 그 편차 또한 압도적이다',
#   '▲ Reddit 조사 ◆ Reddit 유저 비율 ◆ 실질 비율◆ INTJ 지분율  ▲ 쿼라의 MBTI 분포와 실질 분포 사이의 표본비율  INTJ는 본인의 약·단점까지 스스로 강점으로 착각하여, 문제점을 좀처럼 고치지 않고 자기만의 울타리에 갇힐 수도 있다',
#   '위 약점을 어느 정도 타개한 성숙한 INTJ 는 낭만도 중요시 여긴다고 한다',
#   '실제로 INTJ은 성숙한 INTJ와 미숙한 INTJ가 존재하며 본인의 단점을 고친다고 해서 MBTI가 바뀌는 것은 아니라고 한다',
#   '그리고 INTJ들은 성숙한 INTJ로 바뀌고 싶은 욕망이 굉장히 강하다',
#   '강동원 출처김법래 출처김준현 출처손나은 출처류진  출처다원  출처빽가  출처엄기준 출처유준상 출처BoA 출처대열 출처감블러 출처',
#   '수레기  출처각별 출처'],
#  'ISTP': ['MBTI와 16Personalities 성격 유형 중 ISTP 유형을 설명하는 문서',
#   '만능 재주꾼, 백과사전형',
#   '조용하고 과묵하고 절제된 호기심으로 인생을 관찰하며 상황을 파악하는 민감성과 도구를 다루는 뛰어난 능력이 있다',
#   '말이 없으며, 객관적으로 인생을 관찰하는 형이다',
#   '필요 이상으로 자신을 발휘하지 않으며, 일과 관계되지 않는 이상 어떤 상황이나 인간관계에 직접 뛰어들지 않는다',
#   '가능한 에너지 소비를 하지 않으려 하며, 사람에 따라 사실적 자료를 정리, 조직하길 좋아하며 기계를 만지거나 인과관계나 객관적 원리에 관심이 많다',
#   '민첩하게 상황을 파악하는 능력이 있다',
#   '느낌이나 감정, 타인에 대한 마음을 표현하기 어려워한다',
#   '겉보기 특성 - 과묵하며 손재주가 있는 전형적인 장인이나 기능공 스타일의 성격을 가진다',
#   '신체적 능력이 뛰어나 운동에 재능을 보이는 사람도 많다',
#   '다만 표정에서 다소 굳어있는 이미지가 느껴진다',
#   '주의 - 아래 항목은 다른 사람이 각 유형들을 보았을 때 일반적으로 느끼는 특성 위주로 서술되어 있다는 점을 감안할 것',
#   '“아이들에게 여유를 주세요”라고 말하는 부모',
#   'ISTP 부모는 다르다는 것을 존중하고 강요하지 않으므로 자녀가 독립적이고, 자립적인 인간으로 발달하기에 필요한 개인적인 공간을 제공한다',
#   '아이가 성장하고 성숙해짐에 따라 ISTP 부모는 자녀 각자가 어떻게 그 자신이 되어 가는가를 관찰하는 것을 즐긴다',
#   'ISTP 부모는 각 개인의 흥미, 견해와 선택을 수용하고 존중하고자 한다',
#   'ISTP 부모는 자신을 보호하기 위해 권위나 통제를 사용하지 않는다',
#   '대신 비지시적인 접근방식을 좋아한다',
#   'ISTP 부모는 자아충족을 위한 중요한 방법으로써 아이들의 자기단련에 대한 기대가 크다',
#   '결국에는 ISTP 부모는 아이의 기본적인 욕구를 충족시키고 안전하게 보호하기 위해 그들 곁에 있어 주고자한다',
#   '양육 목표는 아이들로 하여금 스스로 생각하게 하며 자신의 행동에 대해 책임감을 가지도록 하는 것이다',
#   '아직 국내에 ISTP만을 다루는 단일 커뮤니티는 없다',
#   '그나마 ISTP포함 여러 유형을 통합적으로 다루는 곳들이 존재한다',
#   '어떤 일이든 노력에 비해 효율이 높다',
#   '시험에 벼락치기로 일관하는 경향이 있다',
#   '노력해서 받는 A보다 벼락치기로 받는 B에 안주하는 편이다',
#   '직장에서 별일 없으면 신경도 안쓰기 때문에 부하 입장에서는 최고의 상사이다',
#   '위선적이거나 가식을 떨지 않는다',
#   '눈에 보이는 모습이 정말 본 모습일 확률이 매우 높다',
#   '간단명료하게 말하는 걸 선호한다',
#   '종교를 믿지 않는 경향이 있다',
#   '다만, 종교를 믿더라도 맹목적으로 믿는 게 아닌 그냥 체험하듯이 믿는 경우도 있다고 한다',
#   '틀에 박힌 생활을 싫어한다',
#   '고정관념이나 편견이 없는 편이다',
#   '융통성이 있으며, 새로운 것에 대한 저항이 크지 않다',
#   '위계와 권위는 군더더기로 간주하며 맹렬히 반항하는 평등주의자이다',
#   '현실감각이 뛰어나며 임기응변에 능하다',
#   '객관적 원리에 관심이 많으며 추상적인 이론이나 개념에 관심이 없다',
#   '정밀을 요하는 일을 잘 해낸다',
#   '도구를 다루는데 관심이 있다',
#   '모험과 스릴을 즐긴다',
#   '체육 분야에서 뛰어난 두각을 나타내는 사람들도 이 유형에서 많이 나오는데, 팀 스포츠보다는 혼자 기술을 연마하는 개인 종목 스포츠를 더 선호한다',
#   '관심분야가 아니면 죽을 때까지 쳐다보지도 않는다',
#   '반면 어떤 일에 꽂히면 질리지도 않고 매우 꾸준히 한다',
#   '계획 짤 때 세세하게 잡지 않고 큰 틀만 짜는 편이다',
#   '충동에 따라 행동하기 때문에 언제라도 일자리를 박차고 떠날 수 있다',
#   '게으를 때는 끝 없이 게으르나 한 번 시작한 일은 끝까지 해낸다',
#   '자신의 일에 고집이 있고 주장이 강하다',
#   '하지만 타인에게 간섭하지는 않는다',
#   '대인관계가 원만하지만 공사의 구별이 뚜렷하다',
#   '인간관계에서도 노력절약을 하기 때문에 필요한 상황이 아니면 먼저 연락을 하지 않고, 깊은 관계일지라도 자주 연락을 하지 않는 편이다',
#   '관심 없는 사람을 만나거나 일을 하는 것을 꺼리며, 그것을 강요하는 사람을 매우 싫어한다',
#   '평소에 자기 사람들 빼고는 남에게 관심이 없다',
#   '이유 없이 자신 혹은 남에게 관심을 가지는 사람을 이해하기 어려워하고 이를 매우 귀찮은 것으로 여긴다',
#   '문제나 상황에 있어서는 바로 입장을 표출하지 않고 지켜보거나, 나서지 않고 관찰하는 것을 좋아한다',
#   '주변에서 일어나는 일에 대해 명확히 알고 있지만 나서서 솔루션을 제시하는 편은 아니다',
#   '개인주의적 성향이 강하고 혼자 있는 시간을 중요히 여긴다',
#   '자의적 혼밥과 독고다이의 달인이다',
#   '일반적으로 조용한 편이나 가끔은 외향적으로 보일 만큼 필요에 따라 사교적이다',
#   '말주변이 별로 없고 어떤 일을 겪어도 표정으로 내색을 않는다',
#   '무표정이 무서워 보인다는 소리를 많이 듣는다',
#   '첫인상이 차갑고 다가가기 어렵다',
#   '상대의 감정이나 생각은 잘 읽지만 눈치를 보며 행동하지는 않는다',
#   '생각은 적극적인데 행동은 소극적이다',
#   '생각이 많지만 이것이 감정적으로 크게 연결되지 않는다',
#   '마음에 없는 소리를 잘 못한다',
#   '영혼이 없다는 소리를 가끔 듣지만 티내지 않으려 노력하며, 앞뒤가 똑같은 사람이 많은 편이다',
#   '띄워준다고 크게 뜨지도 않고 욕 먹는다고 크게 가라앉지도 않는다',
#   '정의감이 있으나 직설적인 말로 타인의 감정을 상하게 할 수 있다',
#   '타인의 일이나 TMI에 매우 무관심한 편이다',
#   '친해지면 반전 매력이 있는 스타일이다',
#   '오는 사람 안 막고 가는 사람 안 잡는다',
#   '연애할 때 사생활 존중을 중요시 하는 편이다',
#   '공학/기술분야군인 , 경찰, 소방관 등 상황판단과 임기응변이 필요한 분야운동선수, 카레이서, 조종사 등',
#   '계획을 세우고 바라던 결과 성취에 필요한 노력을 경주하며 인내심을 함양할 필요가 있다',
#   '편리함 추구 및 노력 절약 경향이 지나칠 수 있으므로, 열성과 적극성을 키워야 한다',
#   '느낌이나 감정, 타인에 대한 고마운 마음을 표현하기 어려워 할 때가 많다',
#   '그러므로 자신의 마음 속에 있는 느낌이나 생각, 정보, 계획을 개방하고 타인과 나누는 노력이 필요하다',
#   '표정이 차갑게 보일 수 있으므로 표정 관리에 신경 쓰는 것이 필요하다',
#   '가끔은 다른 사람들과 함께 하는 일이나 오락 시간을 가질 필요가 있다',
#   'ISTP 유형은 남성이 여성보다 많으며 우리나라의 경우 남자가 9%, 여자가 3% 정도를 차지한다',
#   '내향사고 가 주기능이고 외향감정 이 열등기능인  ISTP 여성은, 주로 F의 정서를 공유하는 우리나라 주류 여성들 사이에 끼기 어려워 할 수 있다',
#   '남자들과 의외로 죽이 잘맞는 경우도 있다지만 개인 성향에 따라 각각 다른 편',
#   '개인적인 성향 중 그들은 <비판적인, 냉철한, 방어적인, 독립적인, 자원이 넘치는> 에서 높은 점수를 기록했다',
#   '학교의 많은 규칙과 요구사항이 힘들 수 있다',
#   '추상적이고 형이상학적인 이론 정립이나 이해에 관심이 없다',
#   '개인 스포츠나 섬세함을 요구하는 종목에서 뛰어난 두각을 보인다',
#   '혼자서 잘 논다',
#   '수천 개의 조각 퍼즐 맞추기도 잘한다',
#   '여아도 전형적인 여자 아이들 놀이를 싫어한다',
#   '긴 설명을 듣고도 대답은 아주 간단하게 한다',
#   'ISTP 마이너 갤러리',
#   '가현  출처 올리비아 혜강소휘 출처김이브 출처김종민  출처 나연  출처류제홍 출처박명수 출처배돈 출처배성재 출처수탉TV 출처유빈 출처유혜주 출처은하  출처이주영 장성규 출처정윤종 출처주우재 출처진호 출처키미 래이쾨넨  한 출처환웅 출처홍진경 출처김달'],
#  'ISFP': ['MBTI와 16Personalities 성격 유형 중 ISFP 유형을 설명하는 문서',
#   '성인군자형',
#   '호기심 많은 예술가형',
#   '말없이 다정하고 온화하며 사람들에게 친절하고 겸손하려고 하나 상대방을 잘 알게 될 때까지 따뜻함을 잘 드러내지 않는다',
#   '동정적이며 자기 능력에 대해 모든 성격 유형 중에서 가장 겸손하고 적응력과 관용이 많다',
#   '자신의 의견이나 가치를 타인에게 강요하지 않으며 의견 충돌을 피하고, 인화를 중시한다',
#   '인간과 관계되는 일을 할 때 자신과 타인의 감정에 지나치게 민감하고, 결정력과 추진력을 기를 필요가 있을 것이다',
#   '겉보기 특성 - 조용하면서 타인에 대한 포용력이 넓어 선량하고 순수하며 착한 사람의 이미지를 가장 많이 풍기는 유형이다',
#   '약간 우유부단한 면도 있다',
#   '문학, 음악, 미술 분야에 어울리는 예술가 기질도 있으며, 사회 봉사 직종에도 어울리는 형태의 성격이다',
#   '잘 나가는 가수나 배우를 비롯한 연예인들을 비롯해서 미술가나 작곡가는 물론이고 평범한 회사 사무직이나 사회봉사직에도 적지않게 분포하는 종류의 성격 타입이다',
#   '',
#   '주의 - 아래 항목은 다른 사람이 각 유형들을 보았을 때 일반적으로 느끼는 특성 위주로 서술되어 있다는 점을 감안할 것',
#   '다음은 ISFP에 관한 국내 커뮤니티들의 목록들이다',
#   '',
#   'I 타입이므로 내향형이지만 I 타입 중에서는 외향 성향이 ISFJ와 함께 가장 강한 편이다',
#   '즐거움을 추구하는 경향도 강하다',
#   'S성향 중에서도 가장 N성향이 강하다',
#   '삶의 현재를 즐기는 사람이다',
#   '그래서 조용하고 온화한 이들이지만 의외의 면에서 충동적인 면을 보이곤 한다',
#   '스트레스가 너무 과해지면 학교나 직장을 갑자기 그만둬버릴 수도 있다',
#   '다른 사람의 부탁을 거절하기 어려워한다',
#   '마음이 순하고 따뜻하며 정이 많다',
#   '사람을 잘 의심하지 않는다',
#   '자신을 내세우지 않는다',
#   '겸손하며, 자기 자랑이 없다',
#   '누구하고나 어떤 사회에서나 맞추어 가며 살 수 있다',
#   '규칙 또는 틀에 묶이는 것을 싫어한다',
#   '결단력이 부족하며 맺고 끊는 맛이 없다',
#   '문학, 음악, 미술 등 예술적인 것에 재능이 있는 경우가 많다',
#   '조용히 있다가 무대에서 끼를 발휘한다 - 몰입이 특징 자연적인 것, 목가적인 것, 전원적인 것에 관심을 가질 가능성이 높다',
#   '인터넷에 자신의 정보를 노출하기 꺼려한다',
#   '프라이버시가 강하기 때문에 상대가 자신에 대해 알려고 하는 것을 꺼린다',
#   '생각은 많은데 행동이 부족하다',
#   '남 눈치를 엄청 많이 본다',
#   '공감 능력이 뛰어나다',
#   '타인을 이해해 주고 많이 맞춰준다',
#   '즐기는 것에 대한 호기심이 많다',
#   '예술적인 감각이 있다',
#   '포용력과 이해력이 많다',
#   '특유의 유머감각이 있기도 하다',
#   '경쟁하는 분위기보다는 편안한 분위기에서 능력을 발휘한다',
#   '미래목표를 설정할 때 자기중심적인 성향을 보이기도 한다',
#   '조직에서 시간이 오래 지나야 인정을 받는다',
#   '딱딱하고 사무적인 사람을 정말 싫어한다',
#   '생각보다 상처를 받거나 예민해지기 쉬운 성격이다',
#   '남을 도와주고서 충분히 대가를 받지 못하기도 하며 때로 너무 착하고 만만해 보인다고 은근히 무시당하는 경우도 있다',
#   '감수성이 매우 풍부한 편인데, 보통 감상에 젖은 내용을 겉으로 드려내려 하지 않고 사진으로 남기거나 홀로 일기장에 끄적이고, 혼자 담아두는 편이다',
#   '디시인사이드 ISFP 마이너갤러리',
#   '추측이 아닌 실제로 검사한 인물만을 기록하며, 출처를 반드시 표기하도록 한다',
#   '유재석 출처윤두준 출처백현  출처지효  출처미나  출처쯔위  출처최병찬  출처설현  출처슬기  출처 윤보미  출처양세찬 출처유민상 출처최유정  출처권정열  출처김영철  출처은지원 출처인교진 출처수진 아이들) 출처김진환  출처노태현  출처태일  출처제노  출처도운  출처아론  I',
#   'M  출처진세연 주니  천지   LE  출처이도  출처수빈  장규리  출처박정우 , 하루토  출처고결  출처신  J',
#   'Seph  출처영빈  출처오재일  출처하상욱   오헬리엉 루베르 출처테라다 타쿠야 출처온유  박세영 김다미  출처  김성식    출처',
#   '짜미깨박이 출처다주 출처듀단 출처멸치 출처수진이 출처승냥이 출처심장에박현서 출처아이템의 인벤토리 출처아름송이 출처해리  출처  이동훈 출처이제동 출처인간젤리 출처에디린 출처이춘향  출처자이원배 출처조현수 출처피유 혜연  출처학살  출처제로 출처'],
#  'INFP': ['MBTI와 16Personalities 성격 유형 중 INFP 유형을 설명하는 문서',
#   '열정적인 중재자, 잔 다르크형',
#   '정열적이고 충실하며 목가적이고, 낭만적이며 내적 신념이 깊다',
#   '마음이 따뜻하고 조용하며 자신이 관계하는 일이나 사람에 대하여 책임감이 강하고 성실하다',
#   '이해심이 많고 관대하며 자신이 지향하는 이상에 대하여 정열적인 신념을 가졌으며, 남을 지배하거나 좋은 인상을 주고자 하는 경향이 거의 없다',
#   '완벽주의적 경향이 있고, 노동의 대가를 넘어서 자신이 하는 일에 의미를 찾고자하는 경향이 있으며, 인간 이해와 인간 복지에 기여할 수 있는 일을 하기를 원한다',
#   '자신의 이상과 현실이 안고 있는 실제 상황을 고려하는 능력이 필요하다',
#   '왜 "잔 다르크" 형인지 궁금해 할 수도 있는데, 바로 본인이 원하는 이상향의 세계를 천천히 만들어 나가는 사람이어서 그렇다',
#   'INFP 개개인마다 인생의 목적은 다르지만, 사회적인 관용을 좋아하는 면에서는 공통된다',
#   '물론 이들도 기본적으로 사람이라 호불호는 마음 속에 있다',
#   '또한 이 별칭 덕에 종종 잔 다르크의 유형까지도 INFP인 양 서술되기도 하는데, 어디까지나 잔다르크에게 씌워진 이미지가 INFP의 이상향에 가까울 뿐, 실제 잔 다르크의 유형은 역사적 기록 자체가 엇갈리는 면이 있어 논란이 있는 상태',
#   'INFP에 해당하는 인구 수는 전체 인구 수의 약 4%, 한국에선 3%로 상당히 소수이다',
#   '그래도 N 성향  중에서는 ENFP 다음으로 많은 편이다',
#   '원래 N 성향 성격은 8종류를 다 합쳐도 전체 인구 중 26% 밖에 되지 않으며, 과반수를 차지하는 나머지 74%는 S 성향 이다',
#   '하지만 외부 활동이 상대적으로 적고 스스로의 성격과 개인적인 영역에 관심이 많은 INFP 성향상, 각종 인터넷 커뮤니티에서는 다른 유형보다 더 쉽게 찾아볼 수 있는 성격이다',
#   '특히 덕후들이 모이는 곳이라면 INTP, INFJ와 함께 약방에 감초처럼 흔하다',
#   '그래서인지 나무위키의 MBTI 성격유형 문서 중 가장 많은 분량을 자랑하며, 거의 실시간 모니터링되다시피 한다',
#   '겉보기 특성은 공상적이며, 인간 관계에서 타인을 직접적으로 지배하려는 성향이 없고 뒤에서 사회적 약자의 편에 서 주기도 한다',
#   '사회에서 외면된 소수자의 모습을 보고 안타까워하면서 뒤에서 눈물을 흘린다',
#   '또한 이상주의적인 면모가 강한데다 가장 감정적인 유형이어서 본인의 가치관을 위해서는 때로 물불 안 가리고 달려들어 싸우는 모습을 보이기도 하며, 불건강하다면 본인 스스로가 정해놓은 가치관의 노예로 살며 싸우는 경우도 생긴다',
#   '하지만 내향성 I가 더욱 강한 일부 INFP들의 경우 좀처럼 불호 취향에 대해서 겉으로 드러내는 일은 없으며, 대신 뒤에서 철저하게 본인이 원치않는 사항에 대해서 비폭력 불복종을 하는 행동을 취하는 경우가 많다',
#   '감정적이고 즉흥적인 면이 강해서 편해 보일수도 있지만, 사실 누구하고든 깊게 어울리기가 조금 힘들고 독고다이를 많이 하는 성격',
#   '그래도 어느 정도의 공감 능력은 있어서 다른 사람의 체면을 생각해서 편을 조금 들어주면서 나름대로 중재자의 역할을 잘하며, 인간관계를 형성하게 되면 인간관계에서 본인의 정서를 온전히 드러내려는 경향이 있어 비슷한 공감대에 한번 친해지면 매우 깊게 어울릴 수도 있는 유형이다',
#   '성격상 가장 어울리는 직업군 자체가 작가, 미술가, 사진가, 디자이너 등인 사실에서도 볼 수 있듯 경제적으로는 평균적으로 볼 때 조금 빈약한 편이고 집에서 가족들하고 지내는 경우도 많다',
#   '나름대로 화목한 환경이 갖추어진 사회에서라면 이들은 스트레스도 최대한 덜 받으면서 꾸준히 일을 하며 돈을 잘 버는 생활에 적응해 나간다',
#   '하지만 지극한 이상주의를 추구하는 이들은 아쉽게도 실용성과, 경제력에 따라서 그 사람의 사회적인 가치가 결정 되어버리는 물질주의, 규율, 사회적인 통념, 센스있는 가식을 중시하고 내리갈굼과 정치적인 다툼, 경쟁이 만연한 사회에서는 가장 쉽게 도태될 수 있는 성격들 중에 하나다',
#   '쉽게 상처를 받아서 그렇기도 하지만 본인 스스로를 센스있는 위선으로 포장하며 이득을 취하는 영악함, 윗사람한테 아부하는 능력, 또 본인의 권리가 침해당했을 때 용감하게 화도 낼 줄 아는 강인한 성향이 없기 때문이다',
#   '그나마 본인이 사회적으로 인정받을 수 있는 차별화된 능력이라도 있으면 모르는데, 그러지 않아서 일도 꼬여버리고 사회생활에서의 인간관계 적응도 안되면 정말 미쳐버릴 수도 있다',
#   '비슷하게 덕후기질이 심해도 INTP의 경우 자아가 강한 편이라 상처를 조금 덜 받는 편이고, INFJ의 경우 상처를 잘 받아도 빨리 풀고 일어서기 때문에 INFP에 비하면 불행 정도가 심하지는 않다',
#   '애초에 본인이 주어진 위치에서 모든 본인의 도리를 철저히 하거나, 여러 사람들하고 정치를 해야 하는 일반적인 직업 생활은 이들 체질과는 맞지 않는다',
#   '스스로 성격을 조금 바꾸려고 노력하고 거기에 성공한다고 해도 일반적인 사회에 적응 정도만 할 수 있는 수준이며 높은 자리까지 올라가기는 생각보다 어렵다',
#   '한마디로 자본주의 사회에 적응하기 가장 힘든 유형 중 하나',
#   'INFP 직장인들은 마음속으로는 예민하지만, 겉보기에 약간 개성파스럽고 상당히 친절하며 부드럽고 둥글둥글한 성격을 가지고 있다',
#   '공적인 공간에서는 나름대로 빼어난 교섭 능력도 보여준다',
#   '인간관계에 적극적이지는 않으나 평상시에 포용력이 좋고 주변 사람들과 두루두루 잘 지내려고 노력하지만 부조리를 강요당하거나 다른 사람한테 휘둘릴 경우 거부감을 표출하든지 아니면 마음속으로 곱씹다가 그 직장을 그냥 떠나버리는 경우도 많다',
#   '낭만이 많은 성격이라 휴식시간에 정적인 취미를 잘 즐기며, 본인 혼자서 하는 관심분야에 취미생활이 하나씩 있는 경우가 많다',
#   '주의 - 아래 항목은 다른 사람이 각 유형들을 보았을 때 일반적으로 느끼는 특성 위주로 서술되어 있다는 점을 감안하시기 바랍니다',
#   '아래에 기술된 내용들은 단순히 감정/사고 기능에 따라 기술한 것이므로 너무 일반화하여 받아들이지 말 것을 권장합니다',
#   '다음은 INFP 성향을 가진 사람들이 선호할 확률이 가장 높은 직업 분야이다',
#   '첫번째 계열이 INFP 성격에 가장 맞는 이상적인 직업군이기는 하지만 돈벌이가 잘 되지 않는 경우가 많으므로 울며 겨자먹기로 일반 회사 사무직으로 많이 빠지는 편이다',
#   '따라서 사회 생활 규범을 중시하는 조직에 상대적으로 만족감이 낮은 편인 INTP와 더불어 직업에 대한 만족도가 많이 낮을 수도 있다',
#   '',
#   '보다시피 잘되면 대박이겠지만, 대부분 쪽박 칠 가능성이 높은 직업군들이 많다',
#   '또한, 신기하게도 지금까지 밝혀진 국내 아이돌 중에서 두번째로 많은 비율을 차지하고 있다',
#   '한국 아이돌 특유의 합숙, 단체 생활에 필요한 둥근 성격이라 그런듯 하다',
#   '첫번째는 ENFP',
#   '잔다르크형 이라는 명칭 때문에 거창한 힘을 가질 성격처럼 보이기도 하나  예상과는 달리 INFP 유형은 돈, 권력, 힘과는 대체적으로 가장 먼 스타일의 성격 유형중에 하나다',
#   '따라서 이들 중에 정치 지도자나 빼어난 군 장성, 부르주아가 나올 확률은 희박하다',
#   '너무 주관적이고 감정이 풍부하기 때문이다',
#   '이들의 삶이 어떤지 탐구해보려면 상대적으로 조용하고, 소박하게 살고 있는 작가나 미술가의 삶을 보는 것이 현명한 방법이다',
#   '또한 과거부터 역사적인 기록은 대부분 힘과 권력을 가진자들에 의해 주로 기록되며, 나머지 기록들은 대부분 세월이 지나면서 희미해지는 경우가 많기 때문에 아무래도 역사적인 INFP들의 삶을 알아보기는 더 어려운 편이다',
#   '물론 이들은 성격 특성상 악명높은 지도자가 될 확률도 거의 없으며, 공상에서 벗어난 현실에서는 굳이 돈과 권력에 끌려 가는 경우도 드물다',
#   '설령 조금 창피하다고 해봐야 배우자와 사이가 안 좋다거나  아니면 술을 마시고 뒤에서 일탈 행동을 하는 정도가 전부',
#   '본인이 원하는 이상향의 사회를 천천히 간접적으로 만들어 나가므로 일종의 조용한 잔다르크라고 할 수는 있다',
#   '다만 이들 스스로가 현재 꿈꾸는 이른바 덕후들에게 관용적인 이상향의 사회가 이들이 살아생전 만들어 질 지는 미지수',
#   '사실 빼어난 리더십과 사회성으로 세상을 직접적으로 더 편하게 바꾸는 성격은 ENFP, ENFJ 계열이다',
#   '신비로운 이미지와 인문주의적인 성격 덕에 창작물에서 주인공으로도 많이 등장하며 이런 현상이 INFP들 한테 마음 속으로 큰 활력을 준다',
#   '스파이더맨에서처럼 실제로 영웅으로 나오기도 하며, 반지의 제왕에서 프로도처럼 영웅들의 보조를 받는 주인공으로도 나온다',
#   '사회적으로 대처 능력이 서투르고 엉뚱한 면이 있기 때문에 현실적인 경쟁 사회에서 과소평가되기 쉬우나 사실 통계적으로 볼때 이들의 지능 수준은 상당히 높은 편이다',
#   'INTP, INTJ가 1, 2위를 겨루고 그 다음 3, 4위가 바로 INFP, INFJ다',
#   '실제로 영재교육기관이나 과학고등학교에서도 흔히 볼 수 있는 성격이다',
#   '그러나 사회적으로 큰 부나 현실적인 명예에 별 관심이 없고 자신의 이상을 갈망하는 INFP 특성상 IQ나 성취 수준에 비해 개인소득과 가구소득은 낮은 편이다',
#   '아마 INFP 유형중 예술가들이 많은 이유도 이 때문일 것',
#   '상대적으로 높은 평균 지능에 비해서 학업 성취도는 INTP, INTJ와 차이가 큰데, 틀에 가두어서 밀어넣는 교육을 대체적으로 매우 안 좋아하기 때문이다',
#   '다음은 INFP에 관해 다루는 국내 커뮤니티들의 목록이다',
#   '',
#   'https://youtu',
#   'be/JNGcTmsa1xA',
#   '기본적으로 성격이 유하고 여리고 착하며 때 묻지 않은 순수함을 가지고 있다',
#   '침착하고 내성적이며 심지어는 수줍음이 많은 사람처럼 비추어지기도 하지만, 마음속은 언제라도 연료가 공급되는 기회가 오면 크게 타오를 수 있는 열정의 불꽃이 숨어있다',
#   '그 불꽃은 주변 사람들에 따라서 큰 불꽃이 될 수도 있고 금방 사라질 수도 있다',
#   '그만큼 사람들한테 영향을 많이 받는 유형이어서 안습이다',
#   '성격이 세심하고 디테일하다',
#   '타인의 아주 작은 부분도 특유의 통찰력으로 캐치해내며 감동을 주곤 한다',
#   '이해력과 포용성이 뛰어난 데다 갈등을 표면화시키는 성격도 아닌지라 상황 대부분을 ‘그럴 수 있지’ 하며 이해하려 노력하고 넘어간다',
#   '내면과 외면의 차이가 크다',
#   '정반대도 있으며 기본적으로 외강내유나 외유내강들이 골고루 분포된 편이다',
#   '엄청난 유리멘탈의 소유자이며, 마음이 여려 사소한 것 에도 깊은 상처를 받고 사소한 것 에도 기분이 아주 좋아진다',
#   '실제로 INFP는 모든 유형 중 우울함에 가장 쉽고 깊게 빠지는 유형이다',
#   '다른 사람들의 시선을 신경을 많이 쓰고, 비판에 약하다',
#   'INFP는 상처를 가장 잘 받는 유형으로 비교적 다른 유형들에 비하여 사람에게 데인 경험이 더 많기에 인간에 대한 기본적인 기대치가 낮다',
#   '일이 조금 힘들어도 사람들과의 관계가 화목한 장소에서는 그냥 잘 적응하며 생활한다',
#   '하지만 내리 갈굼과 정치적인 다툼이 심한 곳에서 사회생활을 하는 것은 INFP들한테 초고난도다',
#   '머릿속에 생각이 너무 복잡하게 많으며, 스트레스 관리가 어렵기 때문',
#   '이런 곳에서 1달, 1년도 아니고 몇 년 이상을 이를 악물고 버티기는 어렵다',
#   '스트레스를 해소하는 능력이 매우 약하다',
#   '그 때문에 건강하지 못한 방법으로 스트레스를 해소하는 경우가 많다',
#   '불건강하거나 이기적인 스타일일 경우 타인한테 이렇게 저렇게 피해를 주는 다른 성격들과는 다르게 INFP는 불건강해지면 자기 자신을 무너트리는 수렁으로 빠지는데 , 때로 주변 사람들과 연락을 끊고 술독이나 게임을 비롯한 쾌락에 물들며 본인의 공상 속에 빠져서 살아간다',
#   '그렇게 불건강해진 INFP는 타인에게 하지도 못하는 심한 말을 자신에게 한다',
#   '자살 확률이 가장 높은 유형으로 매일 자살을 생각하지만 실행력 부족으로 실행은 못 한다',
#   '불건강한 상태에 빠지지 않도록 관리를 잘해야겠지만, 스트레스 관리를 제일 못하는 유형이다',
#   '하지만 불건강한 상태에 빠진 INFP여도 금방 또 사소한 일들로 행복해지는 경우도 있다',
#   '그렇지만 마음속은 곪아가고 있는 상태이다',
#   '화가 나거나 서러우면 눈물부터 흐른다',
#   '눈물이 정말 많다',
#   '감정의 기복이 매우 심하며 지구 내핵부터 오존층까지의 수준이라 카더라  얼굴에서 쉽게 드러난다',
#   '경우에 따라 마음속으로 쉽게 소외감 을 잘 느낀다',
#   '다른 유형들보다 오감으로 느끼는 것들도 많고 예민한데 생각까지 많아서 착각을 많이 한다',
#   '항상 애정을 목말라하는  INFP는 남에게 따뜻한 관심을 받고 싶어 하나 직접적으로 주목받는 일이 생기면 당황하거나 어쩔 줄 몰라 한다',
#   '작은 일에서 칭찬을 받으면 왜 이런 걸로 칭찬하지? 란 생각에 당황한다',
#   '현실에는 더 잘하는 사람들이 많기 때문에 이상에 맞춰서 처음부터 그 수준에 도달하고 싶어하지만 현실은 진짜 못한다',
#   '진짜 잘했을 때 칭찬을 받으면 잘하고 있다는 생각이 들면서 더 잘하고 싶어하지만 부담감에 자꾸 실수한다',
#   '항상 칭찬을 받으면 진짜 잘해서 듣는 칭찬이 맞나? 라는 생각이 들어서 다른 사람들과 비교하고 못했는데 칭찬받은 거면 칭찬해 준 사람한테 미안한 마음이 든다',
#   '자신이 남들과는 다른 특별한 존재라고 생각하고 자신의 가치를 타인의 가치보다 높게 평가해 자기 자신에 대한 애정이 강하다',
#   '다만 인간관계에서 타인을 지배하고자 하는 성향이나, 타인의 사생활에 참견하는 성향은 없다',
#   '그러나 역설적이게도 어느 때는 본인을 남들보다 못하다고 여기고 자기 자신을 제일 싫어한다',
#   '회사나 아니면 가게에서 일을 잘 못 하거나 사회성이 없는 직원을 직설적으로 다그치거나 해고하기 어려워한다',
#   '실제 사람보다 책 또는 영화 속 인물에 매료되곤 한다',
#   '공상적인 성격 때문에 자신이 하고 있는 일에 불만족을 느낄 확률이 높다',
#   '이상주의자인 INFP 특성상 자신의 공상 속 이상과 다른 현실에 괴리감을 느끼며 이는 잦은 불만족으로 연결된다',
#   '본인의 이상을 실현할 수 없다는 것을 누구보다도 잘 아는 일부의 완숙된 INFP는 타인과의 교섭 능력에서 매우 뛰어나다',
#   '완숙된 INFP라면 직업에 대한 만족도는 조금 낮을 수 있어도 원만하게 사회생활을 하는 데는 큰 어려움이 없다',
#   '하지만 그렇지 않은 경우라면 조금 힘들 수도 있다',
#   '현실과 동떨어진 이상주의, 기본적으로 머릿속에 잡생각이 많은 성격, 빡세게 굴러가는 사회의 지배구조와 규율에 대한 불만족 등의 요소들이 걸림돌이 된다',
#   '가식적인 것을 싫어하기 때문에 스스로가 편하게 생각하고 믿는 사람들에겐 자신의 가감 없는 대부분 모습을 솔직히 보여 주려 한다',
#   '혹여나 아직 어색한 사이의 사람에겐 자신의 모습을 꼭꼭 숨기고 보여주지 않을망정 거짓말을 지어내어 말을 하지는 않는 편이다',
#   '규칙을 몸서리치듯 싫어하며  반복되는 일상생활을 마음에 안 들어 한다',
#   '윗사람의 명령과 결정에 모든 것이 좌지우지되는 것도 별로 좋아하지 않는다',
#   '본인만의 사생활 영역을 침해당하는 것을 매우 극도로 싫어한다',
#   '이 때문에 부모에게서 독립하려는 경향이 다른 유형보다도 강하다',
#   '물론 요즘처럼 대한민국 취업 경기가 어려운 시기에는 완벽하게 독립하기가 생각보다 어려운 경우도 있어 정말 안습',
#   '타인이 본인의 스타일을 함부로 간섭하거나 비난, 또는 비웃을 경우에는 공격적으로 변한다',
#   '',
#   'INFJ와 더불어 본인만의 신념, 사상, 가치관이 아주 뚜렷하기 때문에 본인의 가치관에 어긋난다고 생각하는 일에 잘 휘둘리지 않는다',
#   '본인의 가치관과 충돌하는 다른 누군가의 가치관을 듣는다고 해도   잘 흔들리지 않고 바뀌지 않는다',
#   '돈, 권력, 힘 등과 같은 현실적인 부귀영화에 상대적으로 관심이 적은 편이다',
#   '사람에 따라서는 정착하지 못하고 이리저리 유랑하기도 하는데 큰 불편함을 느끼지 않고 살아가기도 한다',
#   '소비를 할 때도 가성비를 많이 따진다',
#   '하지만 관심이 있는 분야라면 가끔 통이 크게 소비하는 경우도 있다',
#   '본인이 생각하는 가치 있는 일에는 생명도 바친다',
#   '때문에 매우 로맨틱하다',
#   '마음에 담은 사람에게 한없이 따뜻하고 충실하게 사랑을 베풀어주며 하고 싶은, 이루고 싶어 하는 일에 대해서 때로 막무가내로 추진하려 하는 경향이 있다',
#   '문제는 이들의 접근 방식 자체가 현실성에서 거리가 먼 경우도 많다는 점',
#   '남들의 기준과는 상관없이 본인 스스로가 원하는 기준에서 의미 있는 일을 하는 것이 인생에서 가장 중요하다고 생각한다',
#   '최악의 상황이나 악한 사람에게서도 좋은 면만을 바라보며 긍정적이고 더 나은 상황을 만들고자 노력한다',
#   '정말 꼴도 보기 싫은 사람이 있어도 표정 관리 정도만 조금 어려울 뿐, 직설적이고 공격적인 말을 절대로 앞에서 하진 않는다',
#   '본인이 이루고 싶어 하는 것에 대해 때로는 은근히 질투가 많고 감정적으로 불안하다',
#   '질투라고 해서 타인을 질투하기보단 잘하고 싶은 욕심은 크지만, 그걸 못하는 자신이 미워서 감정적으로 불안한 경우가 크다',
#   'INFP는 감정의 평화를 최우선으로 생각하기 때문에 감정이 불안해지면 하던 일을 중단하고 자신의 불안함을 없애 줄 다른 일을 찾아 떠난다',
#   '그리고 자신을 불안하게 만든 일은 다시는 안 하는 경우가 많다',
#   '자신의 의견도 중요하지만, 상대방의 의견 또한 중요시하고 매우 관대하게 받아들인다',
#   '자신이 상대방의 의견을 존중해주면 상대방도 자신의 의견을 존중해 줄 것으로 생각하기 때문이다',
#   '선택하는 데 있어, 논리와 계획에 의하기보다는 다소 감정적이고 즉흥적인 경향이 있다',
#   '이상주의가 강해서 자신의 신념과 가치관에 정면으로 배치되는 사안에서는 고집을 굽히지 않을 수 있다',
#   '특히나 공적인 경우가 아닌 사적인 신념에서 지적을 당할 경우 누가 말을 해도 듣지 않고 그냥 적어도 뒤에서는 마이웨이를 계속 취한다',
#   '아름다움과 추함, 선과 악, 도덕과 비도덕에 민감하게 반응한다',
#   '물론 그 기준은 INFP라도 사람마다 다 제각각이다',
#   '공통적으로 학교에서 발생하는 왕따 현상이나, 회사에서 존재하는 정치적인 파벌 싸움에 회의적인 건 사실',
#   '법과 도덕이 충돌할 경우 주로 도덕을 택한다',
#   'INFP가 불건강할 경우 자신이 가진 가치관에 질질 끌려 다니는 경우도 있다',
#   '',
#   '매우 게으르지만 완벽주의적 성향이 있어 때로 지나치게 완벽주의적으로 나간다',
#   '어떠한 일을 시작하는 것을 굉장히 귀찮아하지만, 막상 그 일을 하려고 할 때 본인의 계획대로 순조롭게 진행되지 않거나 결과가 완벽하지 않다고 생각하면 다시 그 일을 재개하는 것을 꺼리며 아예 도중에 그만두거나 시작조차도 하지 않으려 한다',
#   '물론 일을 실행에 옮기는 경우는 그 일에 대해 나름 좋은 감정이 있을 경우이고, 완벽하지 못한 결과물을 도출할 때 극심한 스트레스를 받는다',
#   '아이디어와 계획은 엄청 많이 세워놓으나 실행에 잘 옮기지 못하고 정작 하지 않거나 마무리가 서툴다',
#   '눈치가 굉장히 빠르기 때문에 빠른 속도로 상황을 간파하지만 대부분 모른 체한다',
#   '생각이 너무 많은 탓에 분위기가 조금만 이상해도 모든 걸 알고 자신을 떠보거나 이용하고 있다는 걸 알지만 모른 척해준다',
#   '때로 모른 척하면서 오히려 그들이 원하는 것에 맞춰주기도 한다',
#   '호기심이 많은 성격 때문에 궁금해하는 것도 많고 궁금한 것이 생기면 인터넷을 쥐잡듯 뒤져 정보를 찾아낸다',
#   '이 덕에 잡다한 지식도 상당한 편',
#   '박학다식MBTI문서 중 가장 긴 이유말을 잘 안 하는 편이며 할 말은 거의 다 속으로 하는 경우가 많다',
#   '짜증이나 성질은 내더라도, 진심이 담긴 분노는 거의 표출하지 않는 편이다',
#   '화를 참고 참았다가 한 번에 터뜨릴 순간에도 참는다',
#   '그러나 한계에 도달해서 분노가 한번 터지면 굉장히 무섭고 후폭풍도 장난 아니다',
#   '종종 혼자만의 시간을 꼭 필요로 하기에 그럴 땐 철저하게 혼자 있는다',
#   '그래서 잠수도 종종 타는 편이다',
#   '즉흥적이며 변화가 비슷하다',
#   '집돌이/집순이들이 많다',
#   '당장 후술할 해당 인물만 봐도 꽤 된다',
#   '이들에게 있어서 인생을 살아갈 힘이 나도록 만들어주는 원동력은 본인이 좋아하는 것을 스스로 행하는 마음에서 나온다',
#   '확실한 비전은 있으나 현실은 불확실하다',
#   '구체적인 계획이 있지만, 그것을 달성하기 위하는 과정을 수행하는 데 어려움을 느낀다',
#   "사회화가 조금 덜 된 INFP들은 INTP와 비슷하게 일반인들은 듣지도 보지도 못한 여러 가지 수많은 새로운 시도를 외부에서도 드러내며 하기 때문에 '괴짜 같다'라는 소리를 종종 듣는다",
#   '창의성이 좋다',
#   '다만 이들이 발휘하는 창의성은 현실에서의 일 처리나 자기관리 능력으로 발휘되기보다는, 본인이 원하는 물건이나 스토리를 만들어 내거나 형이상학적인 표현을 만들어내는 종류의 창의성 이라 일반인들의 입장에서 볼때 공감이 안 될 수도 있다',
#   '화목한 환경에서는 의외로 현실주의적이고 실용적인 면도 많이 보여준다',
#   '다만 냉혹한 현실을 잘 소화하지 못해서 불건강해질때 더욱 망상에 잘 빠지는 편이다',
#   '냉혹한 현실 앞에서 초라한 본인의 모습을 마음속으로 채워보기 위해 인터넷이나, 게임 등 가상의 공간 속에서 괜찮은 자신을 은근히 비춰 보이고 싶기 때문',
#   '이런 면에서 볼 때 인터넷이 없었던 시대에도 많은 수의 작가나 미술가들이 불행한 삶을 살았던 경우는 오히려 당연해 보인다',
#   '대화 도중 리액션이 풍부하지만 실제로는 딴생각을 할 때가 많다',
#   '분위기를 잘 탄다',
#   '돌발적인 상황에 대한 순간적인 대처가 빠르다',
#   '누군가를 처음 만났을 때 가장 먼저 보는 것은 인성이다',
#   "INFJ와 더불어 '본인과 맞지 않는 사람'을 빠르게 판단하고 서서히 거리를 둔다",
#   '다만 INFJ가 아예 단칼로 자르는 반면 이쪽은 천천히 거리를 두면서 인연을 끊는다는 차이가 있다',
#   '한 번 일정한 선을 넘어버린 사람에게는 마음의 문을 완전히 닫아버리고 상대방이 알아차리지 못하도록 치밀하게 계획하여 멀어진다',
#   '겉으로는 똑같이 대하기 때문에 당사자는 모른다',
#   'INTJ, ENFP와 더불어 아무하고 쉽고 깊게 친해지긴 힘든 유형이다',
#   '처음 사람을 사귀는 덴 벽이 없는 유형이기에 어느 정도까진 금방 친목을 쌓을 수 있으나 INFP가 인간적으로 타인의 성품을 판단하고 마음에 들이기까진 꽤 많은 시간이 소요된다',
#   'INFP는 처음 본 사람의 호감도가 100에서부터 시작해 이후 조금씩 깎여 나가는 식이다',
#   '또한, 일정 수준 이상 호감도가 내려간 경우 수복하기도 매우 힘들다',
#   '인간관계는 다수처럼 폭넓게 탐색하고 수없이 많은 것이 아닌, 소수를 선호하며 그 관계를 오래도록 유지하고 끊임없이 교류하는 것을 좋아한다',
#   '본인이 상처를 받는 것도 싫어하지만, 남에게 상처나 피해를 주는 걸 정말, 정말로 싫어한다',
#   '그래서 의사 표현할 때는 상대방을 배려해서 최대한 기분이 상하지 않도록 빙빙 돌려 말한다',
#   "'나'의 생각을 드러내어 남이 기분이 나쁘거나 서로 불편할 수 있으면 잘 언급하지 않는다",
#   '본인의 마음이 그렇지 않아도 최소한 앞에서는 다른 남 의견을 존중해주는 행동이라도 보이는 편이다',
#   '그래서 본인만의 구체적인 성격, 뚜렷한 신념과 사상, 그것에 대한 열정 등은 있지만 남이 잘 알 수 없다',
#   'INFP가 신념과 사상을 타인에게 알려줬다면 그 사람을 굉장히 신뢰하는 것이다',
#   '매우 가까운 사이라도 본인만의 선이 확실하다',
#   '마음이 약하고 타인에게 상처를 주지 않기 위해 필터링을 자주 거치기에 아무리 친해도 타인한테 욕이나 무례한 행동을 먼저 하지 않는다',
#   '이런 특성 때문에 자신이 공격 아닌 공격을 받아도 마음 아프지만   그냥 웃으며 넘어가는 경우가 많은데, 특정한 선을 넘으면 겉으로는 똑같이 지내지만, 속으로는 거리를 두려고 한다',
#   '남에게 쓸데없거나 불필요한 말을 잘 하지 않고 평소 정말 조용한 편이며, 애매모호한 정보에 하나하나 다 구체적으로 질문하는 경향이 있다',
#   '개인적인 감정이나 생각을 남에게 잘 털어놓지 않으며 의견을 표출하는 데 있어 매우 조심스러운 탓에  고민이 있어도 잘 털어놓지 못할뿐더러 속앓이가 심하다',
#   '또한 개인주의적 성향도 강해 타인이 본인의 감정과 생각을 비롯한 사생활을 궁금해하는 것도 불편해한다',
#   '하지만 기본적으로 남에게 기대고 싶어 하는 INFP의 내면엔 상대가 내 생각을 알아줬으면 하는 마음이 있다',
#   "그러나 한번 마음을 연 사람에게는 정말 '내가 처음 알던 사람 맞아?'라고 생각할 정도로 말을 많이 한다",
#   '타인이 인간적으로 마음에 들면 그 사람의 관심사도 지지하고 좋아해 준다',
#   '누군가를 깊게 믿는 일이 거의 없기 때문에 본인이 의지하고 싶고 믿음이 가는 사람이 생겼을 때 자신의 모든 걸 내어줄 정도로 헌신한다',
#   '모든 성격유형 중에 INFJ와 더불어 친구나 연인 상대를 고르는데 가장 까다로운 편이다',
#   '타인과 맞지 않는다고 생각될 경우 앞에서는 친절하고 부드러운 모습을 보여주면서도 철저하게 최소한의 거리를 유지하는 모습을 보인다',
#   '기본적으로 개인의 생활을 간섭당하거나, 구속당하는 걸 좋아하지 않으므로 본인 입장에서 상대방이 너무나도 좋지 않은 이상 연애나 결혼도 더 많이 망설이는 편',
#   '타인이 본인의 마음과 기분을 알아주고, 거기에 맞춰서 행동해주기를 바라기 때문에   완숙되지 않은 INFP는 연애도 생각보다 어려울 수 있다',
#   '하지만 정작 같은 INFP가 아닌 이상 이들의 마음을 그 정도로 세밀하게 받아들일 수 있는 사람이 있을지는 의문',
#   '그래서 독신들이 적지는 않은 편이다',
#   '-인간타인의 고민을 군말 없이 잘 들어주고, 타인의 감정에 공감을 잘하는 편이다',
#   '그러나 본인이 느꼈던 경험과 감정을 바탕으로 공감을 시도하기 때문에 자신이 경험하지 못한 것에는 공감을 잘 못 하는 경우가 많다',
#   '이러한 경우 이야기에 최대한 공감하려 노력은 하지만 공감이 안 되는 부분은 공감하고 싶어도 죽어도 못한다',
#   '타인과 만남 약속을 할 땐 대부분 타인의 의견에 맞춘다',
#   '정 이 많아 거절을 잘 못 한다',
#   '설령 거절하게 되더라도 타인의 감정에 신경을 곤두세우며 잘못한 것도 없는데 먼저 미안해한다',
#   '처음 보는 사람에게 말 거는 것보다 안면은 있지만 친하지 않은 사람에게 말 거는 것을 힘들어한다',
#   '대개 사람들과 모임을 싫어하고 낯을 가리지만, 자신과 관심사가 비슷하고 마음이 맞는 사람을 만나면 금방 친해져서 밤을 새워가면서까지 이야기한다',
#   'MBTI의 성격유형 중 MBTI에 가장 깊게 빠져든다',
#   "자기 자신에게 항상 관심이 많으며 '나'를 가장 잘 이해해 주고 설명해 주는 게 MBTI라고 생각하기 때문이다",
#   '기본적으로 덕후들의 성격과 교집합이 상당히 많다',
#   '만화광, 영화광, 게임광, 도서광들도 상당히 있는 편',
#   '맞춤법에 매우 민감하다',
#   '글을 쓸 때 띄어쓰기나 문장 부호, 단어 선택, 글씨체 등에 심혈을 기울인다',
#   '상상력이 풍부하고 몽상가적 기질이 많아 공상에 빠지는 걸 좋아한다',
#   '하지만 이들이 하는 상상 대부분은 현실성 제로의 실현 불가능한 것들이다',
#   '세간의 유행에 잘 따라가지 않는다',
#   '단기 문화 체험, 유적지 및 문화재 관람, 자연환경 감상 등 여행을 좋아하고, 영화, 음악, 책을 좋아한다',
#   '일기를 적거나 사진을 남기는 것처럼 무언가를 기록하고 추억을 남기는 것을 좋아한다',
#   '인간과 종교  또는 신화에  엄청나게 관심이 많다',
#   '때로 신화를 종교처럼 믿기도 하며, 본인 스스로 신화를 창조하기도 한다',
#   '사회의 부조리를 혐오하고 세상을 더 편하고 좋은 곳으로 바꾸는 명예로운 영웅이 되고 싶어 한다',
#   '그래서 여러 가지 사회 문제에 관심이 많다',
#   '언어 학습 에 대한 능력이 뛰어나다',
#   '설령 처음에는 좀 헤매더라도 어느 순간이 되면 실력이 갑자기 늘어난다',
#   '일을 취미처럼 하고 싶다',
#   '그러나 막상 취미가 일이 되면 힘들어한다',
#   '이들에게는 타인에 의한 동기부여가 절대로 통하지 않고, 선생이나 부모에 의해 강제로 변화를 요구받으면 겉으로 노력하는 시늉만 한다',
#   '본인 스스로가 크게 결심하고 변화의 필요성을 느낄 때 비로소 변화를 결심하게 된다',
#   'INFP를 다그치는 건 오히려 역효과를 가져올 수 있다',
#   '부드러운 말로 말을 해주는 것이 훨씬 효과가 좋다',
#   '스트레스를 받을수록 능률이 심하게 떨어지고, 일에 집중하지 못하며, 오히려 본인의 공상 속에 본인을 스스로 가두는 성격이기 때문이다',
#   'INTP와의 차이 - Ne 부기능을 갖고 있는 두 유형 모두 새로운 아이디어나 공상을 하고, Ne가 주기능을 보조하여 발산적인 사고를 할 수 있게 돕는다는 유사점이 있다',
#   '다만 Ti 주기능인 INTP가 객관적인 사실을 바탕으로 하는 과학적인 사고를 발전시켜 공상을 하는거에 초점을 둔다면, Fi 주기능인 INFP의 사고는 대체적으로 더 주관적이고 감성적인 편이다',
#   'INFJ와의 차이 - Ni 주기능인 INFJ는 합리적인 울타리 안에서 공상과 미래에 대한 예측을 하는 편이지만, INFP는 Fi-Ne를 통해 공상이 꼬리에 꼬리를 물고 무한히 뻗어나가는 발산적인 성향을 가진다',
#   'ENFP와의 차이 - ENFP는 E 성향답게 타인 앞에서 더 잘 나서고, 3차 기능인 Te와 주기능 Ne를 갖고 있어서 행동으로 옮기는 걸 좋아하는데, 따라서 무슨 일이든지 원하면 모조리 벌려놓는 충동 성향이 Te 열등인 INFP보다 두드러진다',
#   '또한 꼼꼼함을 요구하는 일이나 반복적인 일에 싫증이나 어려움을 느끼는 ENFP와 달리 INFP는 이에 싫증이나 어려움을 상대적으로 덜 겪는 편이다',
#   'ISFP와의 차이 - 두 유형 모두 Fi 주기능-Te 열등기능을 갖고 있어 감성적이거나 예술적인 면이 강하고 효율적인 판단이나 결단에 어려움을 겪는단 공통점이 있으나, ISFP는 부기능 Se를 갖고 있어 탐구의 대상이 현실 속에 미적인 감각과 센스가 되는 경우가 많지만, INFP는 부기능 Ne를 통해 가상속의 인물을 디자인하고, 현실에 없는 사물을 탐구 대상으로 만들어 내는 것에 더 관심이 많다',
#   'ISTJ - 활동 관계',
#   '상당히 궁합이 좋은 편이다',
#   '꼼꼼하고 효율적인 ISTJ가 INFP의 약한 부분을 잘 보조하여 주고, INFP는 ISTJ에게 창의적인 면이나 감성적인 면을 제공해 줄 수 있기 때문이다',
#   '둘 다 내향형이며 상대방의 3차 기능을 본인이 주기능으로 갖고 있어 서로의 장점을 파악하고 이해할 수 있어서 잘 맞는 편이다',
#   '하지만 INFP의 가치관이나 상상력을 ISTJ가 이해하지 못하거나 공적인 일을 할 때는 서로의 성향 차이로 충돌이 있을 수 있다',
#   'ISFJ - INFP 수혜자-ISFJ 수여자의 이익 관계',
#   '외부를 향한 자기주장이 약한 편이라 본인의 생각과 감정 등을 묻어두는 편인 ISFJ를 INFP가 특유의 통찰로 이해하고 공감해 주고 INFP는 ISFJ 특유의 이타적이며 사려깊은 측면에 감동받는 경우가 많다',
#   '하지만 둘 다 상처를 잘 받는 성격으로 간혹 감정 표현이 적은 ISFJ에게 민감한 INFP가 상처를 받을 수도 있으며 ISFJ는 예민하고 감정의 기복 또한 심한 INFP로 인하여 되려 상처를 받을 수 있다',
#   '그래도 ISFJ는 SJ 성격 치고는 가장 느긋하며 유유자적하기를 좋아한다는 특징을 가지고 있기 때문에 INFP를 잘 이해하는 편이며 비슷하고 잘 맞는다',
#   '',
#   'ESTJ - 이원 관계',
#   '가치관, 취향, 생활방식 등 단 한가지도 맞지 않고 서로 이해가 어려운 관계이다',
#   '물론 케바케로 서로 친하게 지내는 경우도 있지만  거의 대부분은 서로 극혐하는 편이다',
#   '특히 ESTJ가 INFP의 가치관이나 신념, 그리고 개인의 사적인 영역을 함부로 강압적으로 바꾸려는 시도를 했다가는 헬게이트 오픈된다',
#   '특히 공적인 공간에서의 업무처리 면에서 ESTJ가 INFP를 안좋아하는 경우가 많고, INFP가 마지못해 ESTJ의 요구사항을 울며 겨자먹기로 들어준다',
#   'ESTJ 입장에서는 게으르고 잡생각이 많은 INFP를 볼때 속이 터질 수 있고, INFP 입장에서 ESTJ 성격은 너무 팍팍하며 융통성 없고 숨이 막힐 지경이다',
#   '물론 서로의 성격을 바꾸려고 하지 않고 그냥 받아들여 준다면 최강의 상호보완 관계가 될 수도 있다',
#   '다만 서로 그냥 쉽게 받아들이기가 어렵다는게 문제라면 문제',
#   '그래도 INFP는 ESTJ가 하는 거친 발언에 악의가 없다고 생각하면 관계가 좋아질 수 있다',
#   '',
#   'ESFJ - 환상 관계',
#   '사교적인 ESFJ인 만큼 INFP와의 궁합은 무난한 편이다',
#   '그러나 대부분의 경우 ESFJ의 높은 텐션을 부담스러워하는 경우가 대다수이다',
#   '미숙한 ESFJ는 INFP의 상상력과 가치관에  지나치게 개입하고 바꾸려 하기도 하는데, 이러면 당연히 갈등이 생긴다',
#   '',
#   'ISTP - 초자아 관계',
#   '본래 초자아 관계는 성향이 반대라서 서로 이해는 커녕 사이가 매우 안좋은 경우가 많은 관계이지만, 예외적으로 이 두 유형간의 궁합은 밑의 후술할 N유형과 더불어 최고의 궁합으로 여긴다',
#   '물론 초반에는 ISTP 특유의 과묵하고 직설적인 성격과 INFP의 예민한 감수성으로 인해 불편한 경우도 있다',
#   "하지만 '개인의 성향과 사생활을 함부로 침해당하는 것을 극혐함', '남에게 피해주는 것을 싫어함', '계획짜기가 힘듬' 등 서로 비슷한 성향에 동질감을 느껴 친해지는 경우가 많은 편이다, 비단 동일한 친구 및 동료 뿐만 아니라 부모자식, 직장 상사 및 부하직원간의 관계로 만난다 해도 이러한 공통된 성향이 서로 플러스 점수가 되서 원만하게 지낸다",
#   '또한 ISTP는 공감능력이 미숙한 편인데, 이러한 점을 INFP가 보완해주기 때문에 긍정적인 관계를 이어나갈 수 있다',
#   '',
#   'ISFP - 비교 관계',
#   '이상주의적인 N성향, 현실주의적인 S성향의 차이가 약간 있지만 이것을 제외하고는 서로 비슷한 점이 많기 때문에 궁합이 좋다',
#   '감정적이고 예민한 성격부터 시작해서 타인한테 쓴소리를 잘 못하는 온화한 성품, 느긋한 성향, 사생활을 침해 받는것을 싫어하는 것 등등 유사점이 많다',
#   '그리고 ISFP유형은 S유형중에 N성향이 가장 큰 유형이다',
#   'ESTP - 갈등 관계',
#   'ESTP의 경우 특유의 강한 행동력과 빠른 판단력을 갖고 있어 우유부단한 INFP에게 좋은 영향을 줄 수 있다',
#   '센스 좋은 ESTP들이 INFP가 힘들어할 때 부담스럽지 않게 다독이거나, 아니면 그 힘들어하는 원인을 금세 바로잡아 주기도 한다',
#   '반대로 INFP도 Ni 열등 이라 나중 일 생각 안 하고 행동하는 ESTP를 바로잡아 주기도 하는 등 서로의 다른 점으로 커버해주는 편이다',
#   '다만 ESTP의 Ni 열등을 INFP가 싫어하거나, INFP가 감성에 젖은 모습이나 우유부단한 모습을 보일 때 ESTP가 이해하지 못하는 등의 이유로 충돌할 가능성도 높다',
#   'ESFP - ESFP 감독자-INFP 감독 대상자의 감독 관계',
#   '따뜻하고 사교성 넘치는 ESFP가 INFP와의 관계에서 INFP의 감성을 받아 주고 약점인 행동력도 보완해 주는 전형적인 감독 관계',
#   '두 유형 모두 Fi를 주-부기능으로 갖고 있는 만큼 어렵지 않게 원만한 인간관계를 형성할 수 있다',
#   '',
#   'INFP - 동일 관계',
#   '다른 유형보다 서로가 있을 때 마음을 터놓기 수월하며 활발하고, 대화도 자주 한다',
#   '서로 상대방을 배려하는 모습이 크기 때문에 INFP 유형의 사람들이 만나면 서로 상처받는 일은 많지 않다고 볼수 있다',
#   '약속을 미루거나 안읽씹을 자주하므로 자발적으로 행하는 만남은 많지 않다',
#   '그러나 만나면 편한 관계인 것은 확실하다',
#   '다만 신념의 차이로 인해 다투는 경우도 종종 있는 편이다',
#   '신념의 대결 자신의 너드 같은 성격 때문에 처음 만났을 땐 자기가 싫어하는 자기의 모습이 보이는 상대방의 너드 같은 성격과 너드 같은 말투를 싫어해서 동족 혐오를 하는 듯 보이나, 서로 시간이 지나고 상대방에 대해서 알게 되면 애틋하게 생각한다',
#   '그리고 너드같은 사람을 제일 좋아하면서 제일 싫어한다',
#   'INTP - 유사 관계',
#   '완숙되고 사회화가 어느정도 된 INTP라면 서로 이상주의적인 공통점이 매우 많은 유형이다',
#   '뜬금없는 컨셉이나 가상현실 등등 공통적으로 좋아하는 취미나 분야도 많고 개인주의적 취향도 비슷하여 서로 정말 일맥상통하는 관계이다',
#   "다만 사회화가 별로 안된 INTP라면 '그딴건 뭐하러 하는거야?' 또는 '그 맛도 없는걸 왜 이렇게 좋아해?' 같이 너무 솔직하게 직설적인 말을 해서 INFP한테 상처를 주거나 분노케 해 다툴 수도 있다",
#   '또한 INTP의 친할수록 현실적으로 문제를 분석하고 해결방안을 제안하는 행위가 위로나 공감이 필요해 이야기를 꺼낸 INFP의 의도와 맞지 않아 서로 상처받는 경우도 있다',
#   'ENTP - INFP 감독자-ENTP 감독 대상자의 감독 관계',
#   '완숙되고 농담 따먹기에 익숙한 INFP라면 ENTP와는 서로 이상주의적인 죽이 잘 맞는다',
#   '주로 ENTP가 이상한 짓 을 하면 INFP가 따라 웃어준다',
#   'INFP는 일반적으로 리액션이 큰 편이다',
#   '이런 리액션이 큰 것을 좋아하는 ENTP가 INFP에게 짖궃은 장난을 많이친다',
#   'ENTP는 그들이 자신의 주관을 펼칠때 그 생각이 공감이 안 되더라도 반응을 보여주는 INFP덕분에 자신이 인정받고 있다고 생각한다',
#   '그러나 ENTP는 직설적이고 짖궃은 면이 있기 때문에 INFP에게 의도치 않게 상처를 줄 수 있으므로 이런 부분에선 주의가 필요하다',
#   '특히 ENTP와 죽이 척척 맞기도하나 ENTP 부서중 고쳐야할 항목은 INFP와의 관계유지성중 가장 큰 타격이 되는 부분이므로 주의가 필요하다',
#   '그러나 서로가 배려하면 천생연분인데 서로 공통점이 많은 유형이며 상상력이 풍부하면서도 실행력은 거의 제로인 점이 같아서 서로 끌린다',
#   '‘나만 저런 생각을 하는 게 아니었구나!’ 라며 여러 터무니 없는 아이디어를 공유하며 재미있어 한다',
#   '이때 옆에 있는 SJ 친구는 이 답 없는 케미에 고통받기도 한다',
#   '',
#   'INFJ - 오해  관계',
#   '논리적인 J성향, 감성적인 P성향의 차이가 약간 있지만 이것을 제외하고는 ISFP처럼 서로 비슷한 점이 많기 때문에 무난하게 잘맞으며 같이 있으면 편한 사이이다',
#   'INFP의 따뜻함에 INFJ가 감명을 자주 받고, INFP는 INFJ의 상당히 높은 통찰력에 감탄하는 경우가 있다',
#   '서로 선을 잘 지키는 성격이기도 하지만 페르소나를 자주 사용하고 어떤 인간관계에서도 본인의 속을 쉽게 드러내려 하지 않는 INFJ와 달리 깊은 인간관계에서 속마음을 완전히 열려 하는 INFP의 성향 상 충돌이 있는 경우가 있다',
#   '이러한 과정을 좋게 해결하는 경우도 있으나, 상처받은 INFP가 먼저 떠나가거나 INFJ가 도어 슬램으로 관계를 완전히 끊어버리는 경우도 있다',
#   'INTJ - INTJ 수혜자-INFP 수여자의 이익 관계',
#   '두 유형 다 오타쿠 기질이 있어서 서로 맞을 확률이 높으나,  관심분야가 다르다면 좋아하지 않을 수도 있다',
#   '그래도 공통된 개인주의 성향때문에 서로 존중하는 편이고 감정교감과 논리적 사고를 서로 공유하고 보완해주기 때문에 궁합이 좋은 관계이다',
#   'ENFP - 거울 관계',
#   '이상주의자에 감정도 풍부하고 사교적인 기질로 INFP가 밖으로 나오거나 이상을 조금이나마 현실로 만들도록 유도할 수 있어 서로 잘 맞는다',
#   '주로 ENFP가 INFP에게 친구를 만들어주는 경우가 많으며 ENFP는 그런 일을 보람차게 여긴다',
#   '마음이 착한 ENFP는 INFP에게 상냥한 면모를 자주 보여주고 INFP는 특유의 세심함으로 ENFP의 디테일까지 캐치하여 서로 좋은 영향을 준다',
#   '가끔가다 INFP가 아주 혈기왕성한 ENFP 와의 관계에선 기가 빨린다는 등의 얘기를 하기도 하지만 대부분의 ENFP들과는 잘 맞는 편',
#   'ENFJ - 대척 관계',
#   '언변능숙형답게 말을 무척 조심스럽게 잘하는 성격이라 INFP가 상처를 받지 않고 어울릴 수 있는 성격 유형 중 하나',
#   '싸우면서 만난다는 커플도 많고 잘 만난다는 커플도 많다',
#   'INFP가 정해놓은 선을 알고 그 선을 넘지않는 선에서 적당히 조심스럽게 다가온다',
#   '가끔씩 오글거리지만 말을 예쁘게 하는 ENFJ한테 호감을 느끼고 좋아하고 잘 따르는 INFP들이 많다고 한다',
#   '실제로 INFP와 가장 죽이 잘 맞는 유형이기도 하다',
#   '또한 ENFJ는 불건강한 INFP를 건강한 모습으로 변화시키는데 능숙한 유형이다',
#   '불건강한 INFP가 ENFJ를 만나면 건강한 INFP로 변하고 마음속에 꺼져가던 작은 불꽃이 큰 불꽃으로 변하는 열정을 경험할 수 있다',
#   '그러나 ENFJ가 곁에서 사라지는 순간 다시 주변 사람들 한테 영향받고 불건강한 INFP로 돌아가는 건 한 순간이다',
#   'ENTJ - 반 이원 관계',
#   '두 유형 모두 이상주의적이고, INFP의 이상을 조금이나마 현실로 만들어줄 수 있어서 최강의 궁합이라고도 한다',
#   '또한 INFP는 ENTJ의 감정을 세밀하게 잘 헤아려준다',
#   'ENTJ가 당근과 채찍을 적절히 사용한다',
#   'INFP의 감정이 상하지 않을 정도로 간을 보면서 장난을 치고, 이 행동이 상대가 싫어서 하는 것이 아니라는 점을 분명하게 인지시킨다',
#   '특히 극강의 천생연분인데 사랑을 주제로 한 작품 에 가장 많이 등장하는 조합이다',
#   '서로의 열등 기능을 보완해주고, 어떤 관계로 만나든 매우 다정하고 좋은 관계성을 가지고 있다',
#   '처음에는 서로 다가서기 힘들어 하지만, 막상 친해지면 연인으로도 친구로도 매우 잘 맞다',
#   'INFP는 때때로 호탕하지만 냉담하다는 평가를 받는 ENTJ의 따뜻함을 유일하게 알아채주고, ENTJ는 감성 속에 둥둥 떠다니는 인프피를 적절히 잡아줄 수 있다',
#   '은근히 세심한 ENTJ는 의외로 INFP를 서운하게 하지 않는다',
#   'INFP는 ENTJ가 지쳤을 때 절대 홀로 놔두지 않는다',
#   '그리고 두 유형은 세심한 부분에서 굉장히 잘 맞는다',
#   '남들과 자기 자신조차 무심코 지나칠 수 있는 서로의 세심한 부분을 잘 알아차리고, 그에 대해 어떻게 대응해야 하는지도 잘 알고 있다',
#   '공적인 관계에서도, 사적인 관계에서도',
#   '매섭고 불합리한 현실이  백일몽같은 이상을 억누르더라도  스스로 마음이 흔들리지 않도록 노력해야 한다',
#   '사회는 생각보다 팍팍하고 매정할 수도 있다',
#   '현실과 이상세계를 구분하는 능력이 필요하며, 때로는 대인관계에서 자신의 가치관에 맞지 않는 것이라도 융통성을 보일 필요가 있다',
#   '너무 늘어지지 않는 꾸준함을 기르기 위해서 아주 작은 일부터 통제력을 갖는 것이 필요하다',
#   '간혹 본인의 창작물에 대해 타인이 혹평을 해도 마음이 흔들리지 않고 이성적으로 본인의 생각과 철학을 설명, 전달할 수 있는 강인한 용기를 기르면 좋다',
#   '불건강할 경우 건강한 방식으로 스트레스와 감정을 해소하려는 의지를 갖는 것이 중요하다',
#   '현실의 벽에 좌절하기 가장 쉽고 상처를 받기도 쉬운 성격인만큼, 몸과 마음을 건강하게 하도록 노력하는것이 가장 중요한 성격이다',
#   'SNS, 게임, 술, 담배, 포르노, 유흥을 줄이고 축구, 농구, 야구, 배구같이 여럿이서 하거나 2명이서 쉽게 할 수 있는 탁구나 배드민턴같은 스포츠 활동처럼 단체 협력 활동에 자주 참여를 하는것이 좋다',
#   '본인의 운동신경이 안 좋다면 헬스나 수영을 배우거나 해보는것도 좋은 생각이다',
#   '공적인 장소가 아닌이상 본인의 기쁨, 슬픔과 같은 감정을 겉으로 표현할줄 아는 외향감정 기능을 기르면 연애를 하기가 아무래도 더 편해진다',
#   '창의력이 뛰어나지만 아이디어를 많이 내어도 금방 지우기 일쑤 이다',
#   '이럴 때는 시간이 촉박하지 않도록 충분히 잡고 종이 위에  브레인스토밍을 하듯이 천천히, 많이 적어 본다',
#   '조금 이상해 보인다 할지라도 다듬는 단계에서 좋은 요소가 될 수 있으니 우선은 다 적어보고, 자신이 태초에 의도한 주제와 관련성이 높은 문장에   나 밑줄 등으로 묶는다',
#   '추출한 문장들을 다양하게 배치하고 계속 첨가해보며  완성해 나간다',
#   '완성한 이후에는 자신의 창작물에 어느 정도 자부심을 가지고 있을 필요가 있다',
#   '위와 같은 과정을 여러 번 연습하다 보면 작품성이 높을 글을 많이 써 내려갈 수 있다',
#   '믿고 의지하고 싶은 사람이 생기더라도 상대방에게 모든걸 걸면서까지 다 퍼주는 일은 자제해야한다',
# ...
#   '“거시적인” 그들은 상황에 따른 대안과 가능성을 제시한다',
#   '뿐만 아니라 객관적이고 논리적이어서 ENTP 부모는 자녀가 스스로 판단하고 선택하게하여 그로 인한 결과를 통해 학습이 일어나기를 원한다',
#   'ENTP 부모는 자원이 풍부하고 행동 지향적이다',
#   '그들은 아이들과 함께 어딘가에 가기를 좋아하고 함께 행동하는 것을 좋아하며 삶이 제시하는 모든 것을 탐험하고자 한다',
#   '그들은 규칙, 일상사, 일정에 중점을 덜 두고자 한다',
#   '아이들에게 새로운 개념과 활동을 소개하고 도전해보게 하며 그들의 지적발달을 자극하는 것을 우선적으로 둔다',
#   '다음은 ENTP에 관해 다루는 국내 커뮤니티들의 목록이다',
#   '',
#   '대개 팔방미인, 다재다능이다',
#   '두뇌회전이 빠른 편이고 어떤 사안에 대한 대략적인 이해가 매우 뛰어나다',
#   '발상력이 매우 좋아 단기적인 문제 해결에 있어 효율 및 성과는 뛰어나지만, 장기적인 노력이 필요한 경우 노력을 꾸준히 투입하기가 어렵다',
#   '특성상 벼락치기를 선호하는 경우가 많고 노력 대비 결과가 상당히 괜찮은 편이다',
#   '심지어 시험 공부를 하지 않고도 결과가 잘 나오기도 한다',
#   '그러나 장기적으로 공부해야 하는 시험에는 성과가 좋지 못할 수 있다',
#   '빠르게 눈치채고 있지만 상황을 저울질 해본뒤 눈치볼 필요가 없다고 느껴지면 마이웨이를 달리는 경우가 많다',
#   '눈치 없다는 소리를 꽤 듣는 이유 중 하나',
#   '애초에 주변의 시선에 초점을 두는 유형이 아니라 타인의 눈치를 보는걸 진짜로 잊어먹는 경우가 흔한 편이다',
#   '눈치 없다는 소리를 꽤 듣는 이유 중 둘',
#   '타인의 의중을 섬세하게 고려해서 맞춰주는 눈치가 뛰어난건 아니지만, 남들이 놓칠법한 부분은 오히려 쉽게 눈치채는 경향이 강하다',
#   '자존감이 굉장히 높고 자신에 대한 확신이 강하다',
#   '복잡한 문제를 쉽게 해결할 지름길 내지 꼼수를 발견하는데 능하다항상 새로운 것을 추구한다',
#   '마음만 먹으면 못하는 것이 없다',
#   '이것저것 손대는 것이 많다',
#   '일을 시작하는 데 있어 추진력은 좋지만 뒷심이 부족한 편',
#   '즉, 용두사미가 되기 쉽다',
#   '반복적으로 꾸준히 해나가면 해결되는 문제보다는 차라리 비반복적인 어려운 문제를 해결하는 것이 더 수월하다',
#   '어떤 유형의 사람이든간에 편견 없이 보려고 한다',
#   '처음 보는 사람에게 말 거는 데 거리낌이 없다',
#   '분위기나 타인의 생각을 읽고 이해하는 능력이 뛰어나고, 대화를 매력적으로 이끌어 나간다',
#   '대화에 있어서는 자신의 말에 대한 상대의 반응이 어떤지 꽤 신경 쓰는 편',
#   '타인의 일에 크게 관심이 없고, 자신이 인정받고 싶어하는 분야 외에는 타인이 자신을 어떻게 평가하는지 관심 없다',
#   '모든 성격 유형 중 스트레스가 가장 적어보인다',
#   '자기애가 강하며, 자기 합리화를 잘 한다',
#   '자신의 아이디어로 남을 이끌어가는 것을 좋아하나 지나친 간섭은 잘 하지 않는다',
#   '자신의 생각을 거리낌 없이 말한다',
#   '토론이나 논쟁을 좋아하며 자신의 의견으로 끝을 맺어야 하는 성격이다',
#   '자기주관과 가치관이 매우 뚜렷하다',
#   '좋아하는 사람과 싫어하는 사람 구분이 확실하다',
#   'E 타입이기에 기본적으로 외향적이긴 하나 E 타입 중에서는 내향 성향이 가장 강한 편이다',
#   '겉으로 드러나는 성격에 비해 개인주의 성향이 강하며 독립적이다',
#   '다른 사람들이 자신을 무시하는 것을 굉장히 싫어한다',
#   '대개 겉과 속이 같은 사람들이다',
#   '인간관계가 자유롭다',
#   '온갖 것에 관심이 많다',
#   '위험을 감수해서라도 새로운 시도를 하는 편이며 모험심이 강하다',
#   '관심 있는 분야가 아니면 한 번 들은 얘기를 또 듣는 걸 극도로 싫어한다',
#   '뒤끝이 없고 애초에 잘 화가 나거나 삐지는 편이 아니다',
#   '단어 하나로 2시간도 이야기 한다',
#   '일상적이고 반복되는 일은 지루하고 힘들어 한다',
#   '경쟁심이 강한 편이다',
#   '빠뜨리거나 빼먹는 일이 많다',
#   '다른 누구의 설득되지 않는 권유나 참견은 질색한다',
#   '자신의 가치관이 우선이며 기존의 전통이나 권위, 규범은 답답해하는 편',
#   '새로운 아이디어나 창의적인 발상을 잘 낸다',
#   '또는 기발한 아이디어나 창의적인 발상이 필요한 직업을 가지는 경우가 많다',
#   '학창시절 때 머리는 좋은데 공부를 안 한다는 소리를 많이 들어온다',
#   '자신의 판단에 따라 행동한다',
#   '말을 나오는 대로 막 할 수 있다',
#   '남이 하는 거 보고 맞춰 가는 분야의 일은 싫어한다',
#   '자기주장이 강한 것에 비해 정당한 비판에 대한 수용이 빠르다',
#   '호감의 표시 또는 친해지고 싶은 이유로 놀리거나 짓궂은 장난을 좋아한다',
#   '반응이 귀엽거나 찰질수록 더 좋아하는 경향이 있다',
#   '동성, 이성 가릴거없이 아무한테나 멘트를 잘치지만 정말 좋아하는 사람앞에서는 말이 과하게 많아지거나 아예 없어지거나 둘 중 하나다',
#   'ENTP에게 절대적으로 존경하는 사람이 생기는 일은 드물기에, 존경하는 사람이 생기면 자신의 가치관에 존경하는 사람의 가치관이 혼합될 확률이 높다',
#   '자기와 의견이 다른데  ‘그래 맞아~’ 하면서 넘겼다면 정말 그 말이 맞다고 생각해서가 아니라 토론할 가치를 못 느껴서일 가능성이 크다',
#   'ENTP이 왜? 라고 묻거나 왜그렇게 생각해? 라고 묻는것은 꼽주거나 비꼬는 것이 아닌 순수히 궁금해서 물어본 가능성이 크다',
#   '친구가 문제를 겪고있을 때, 감정적인 지지보다는 문제의 해결방법을 제공하는 방식을 선호한다',
#   '다양한 분야에 관심이 많고 그만큼 아는 것들도 상식도 많아 똑똑하지만 막상 시험 공부를 하지 않아 학교 성적은 중위권에 머무는 경우가 많다',
#   '가끔씩 기발한 아이디어가 생각나서 메모장에 두루뭉실한 계획을 많이 써 놓으나 실천하지 않은 것이 많다',
#   '사람들과 얘기하는 것을 좋아해 밝고 활동적이면서도 독립적이고 사람들과의 관계를 다른 부분들보다 우선시 하는 편은 아니라 겉으로 봤을때 차갑고 무관심해 보일 수도 있다',
#   '동정심, 정이 많거나 가지고 있는 가치관이 굉장히 도덕적인 경우 전형적인 ENTP 같지 않아 구분하기 힘들 수도 있지만 오래 보다보면 ENTP 유형의 사람들은 구분이 확실히 될 정도로 뚜렷한 성향을 가지고 있는 유형이다',
#   '팔로워보다 리더가 되기를 원한다',
#   '주변에서 4차원이란 말을 듣기도 한다',
#   '자기애가 강한 편이다',
#   '자신은 어떻게든 성공할 것이라고 생각한다',
#   '감정적이기보다는 논리적이다',
#   '새로운 아이디어와 모델에 몰입하여 현재의 중요성을 잊기 쉽다',
#   '다른 사람의 노력을 인정하고 칭찬, 격려 등의 표시를 할 필요가 있다',
#   '일상규범, 표준절차를 신경쓰지 않을 수 있기에, 우선순위와 일정계획을 세울 필요가 있다',
#   '말을 할 때 타인이 어떻게 느낄까 먼저 생각하는 것이 필요하다',
#   '아이디어는 매우 훌륭하나 지속성 혹은 뚝심이 없을 수 있기에, 일의 끝마무리에 대한 인내심이 가질 필요가 있다',
#   '재미있고 잘 어울리기 때문에 여러 부류의 친구들이 좋아한다',
#   '반면 지나치게 눈치를 보지 않고 행동하는 나머지 또래 애들에게 미움을 사는 경우 또한 적잖은 편',
#   '질문이 많은 편이다',
#   '때론 지나칠 정도로',
#   '하는 것이 무엇이든지 간에 순간 몰입을 잘한다',
#   '학교나 학원의 분위기를 축제같이 바꾸어 준다',
#   '에너지가 많고 느긋한 선생님을 좋아한다',
#   '현장학습이나 바깥에서 하는 활동을 좋아한다',
#   '사람이나 동물의 얼굴표정이나 몸동작 흉내를 잘 낸다',
#   '적응력이 강하고 느긋하고 자기 자신을 심각하게 받아들이지 않는다',
#   '새로운 것을 익히는 것을 즐긴다',
#   '종종 학교생활이 지루할 수 있다',
#   '성격이 급하다',
#   'ENTP 들의 모임',
#   '노무현 출처 이영지 출처 퀸와사비 출처 제시 출처설리 출처정준영 출처세정 출처혜린  출처김동완  출처박진영  출처이찬혁  출처육성재   출처Young K  출처윤산하  박경  출처주연 , 선우  출처제이 시연  출처  시현 민기  출처김수찬 출처염따 출처코드 쿤스트 출처박규정  출처한예슬 출처라미란 출처이수민 강민아 출처정혁  출처이정현  출처최시은  출처김민아  출처강재준  출처박은혁 출처로즈하 출처꿩유갱  덕자허팝 출처 양띵 출처 서새봄 출처  머독  출처김대호  출처tape2'],
#  'ESTJ': ['MBTI와 16Personalities 성격 유형 중 ESTJ 유형을 설명하는 문서',
#   '엄격한 관리자, 사업가형 ESTJ  구체적이고 현실적이고 사실적이며 활동을 조직화하고 주도해 나가는 지도력이 있다',
#   '실질적이고 현실감각이 뛰어나며 일을 조직하고 계획하여 추진시키는 능력이 있다',
#   '기계분야나 행정 분야에 재능을 지녔으며, 체계적으로 사업체나 조직체를 이끌어 나간다',
#   '타고난 지도자로서 일의 목표를 설정하고, 지시하고 결정하고 이행하는 능력이 있다',
#   '속단 속결하는 경향과 지나치게 업무 위주로 사람을 대하는 경향이 있으므로 인간 중심의 가치와 타인의 감정을 충분히 고려해야 한다',
#   '또 미래의 가능성보다 현재의 사실을 추구하기 때문에 현실적, 실용적인 면이 강하다',
#   '겉보기 특성 - 현실감이 빼어나고 리더쉽이 있으므로 경제력이 가장 좋은 성격 중에 하나이며, 상당히 조직적이고 절도있으며 무게감이 다소 있는 선배나, 교육자, 상사, 사장, 특유의 가부장적인 아버지의 모습을 많이 보여주는 유형이다',
#   '겉보기에 철저하고 엄격해 보일 수는 있지만 완숙된 스타일이라면 본인 주변에 있는 사람들한테 상당히 빼어난 의리와 배려를 보여주기도 한다',
#   '스스로 빡세게 일을 하며, 현실적이면서 커다란 도전을 매우 좋아하는 유형이기도 하다',
#   'MBTI 유형 중 매우 흔한 편이다',
#   '인구비율 순위에서 항상 4위 이내의 최상위권에 속한다',
#   '주의 - 아래 항목은 다른 사람이 각 유형들을 보았을 때 일반적으로 느끼는 특성 위주로 서술되어 있다는 점을 감안할 것',
#   '감정이 잘 드러나 직설적인 언어로 표현한다',
#   '모든 게 제자리에 있어야 하며 계획이 틀어지는 것을 싫어한다',
#   '리더 역할을 선호하지는 않으나 막상 맡으면 잘한다',
#   '논리적, 분석적 객관적이며 분명한 규칙을 중요시하고 그에 따라 행동하고 일을 추진하고 완성한다',
#   '정치 성향 면에서 중도 성향이 최하위, 보수주의 성향은 가장 강한 것으로 나타났다',
#   '고집이 있지만 논리적으로 긍정하게 되면 더 이상 고집을 피우지 않는다',
#   '호불호가 확실하다',
#   '일을 잘해 놓고도 존경받는 일이 드물 수 있다',
#   '집단에서 분위기 보다는 목적 의식을 중요시한다',
#   '경영자적인 재질, 가지고 있는것을 적절하게 활용하는데 탁월한 자질을 지녔다',
#   '한 번 시작한 일을 철저하게 뿌리 뽑는다',
#   '전철을 탈 때도 어느 칸에 타야 갈아타기 편한지 계산하고 탄다',
#   '예약과 계획의 생활화독창력, 창의력이 부족하다',
#   '다만 자기 분야에 대해서는 어느 정도 경험만 쌓이면 그 경험을 바탕으로한 실용성 있는 발상을 해내는데에 있어선 제한적으로 창의적인 면모가 드러나곤 한다',
#   '매우 진취적이고 혁신적이며, 현실적인 도전정신이 강한 야심가다',
#   '상당히 출세지향적이다',
#   '여유로우면 불안하다',
#   '남의 말에 공감하는 척하지만 속으론 상황판단 한다',
#   '말과 걸음이 빠르다',
#   '외로움을 별로 타지 않는다',
#   '지배하려는 성격이 있어도 양보는 잘 하지 않는다',
#   '감동시키기보다는 이해시키길 원한다',
#   '싸움을 싫어하지만 싸워서 지는 것도 싫어한다',
#   '가만히 있으면 피곤하다',
#   'ENTJ 정도를 제외하면 가장 평균 연봉이 높은 성격이며  권력자가 될 확률도 다른 성격보다 더 높다',
#   '하지만 ENTJ는 수적으로 상당히 드물기 때문에 수적인 우세까지 포함한다면 아무래도 ESTJ가 가장 사회적으로 많이 성공하는 성격이라고 할 수 있다',
#   '최고의 결과를 얻기위해 매우 계획적이고 조직적으로 움직이며 실용성과 규율을 중시하는 성격이 사회의 현실과도 많이 일치한다',
#   '그래서 사람들이 성격 바꾸기를 시도할 때 가장 많이 벤치마킹하는 성격 유형이기도 하다',
#   '마초적인 서열사회에 적응을 잘 하는편이다',
#   '하지만 윗사람하고 극단적인 마찰이 생길 경우  싸우거나 때로는 아예 사표를 내기도 한다',
#   '현실적인 아이템과 서비스를 제공하는 모든 비즈니스 분야군인•경찰 , 법조계 운동선수, 감독, 코치사업가',
#   '지수  출처도한세 데프콘 출처문세윤 출처한채영 출처이지혜 출처김준수 출처김동한  출처김립  출처김민규  김소영  출처민영기 출처뱀뱀 출처여원  출처제인   창조  출처제시카  출처정원',
#   '소니쇼 출처손수호  조응천  출처 허경영 아구  출처포니  인스타그램 라이브에서 언급'],
#  'ESFJ': ['MBTI와 16Personalities 성격 유형 중 ESFJ 유형을 설명하는 문서',
#   '사교적인 외교관친선도모형',
#   '동정심이 많고 다른 사람에게 관심을 쏟고 인화를 중시한다',
#   '타고난 협력자로서 동료애가 많고 친절하며 능동적인 구성원이다',
#   '이야기하기를 즐기며 정리 정돈을 잘하고 참을성이 많고 다른 사람들을 잘 도와준다',
#   '사람을 다루고 행동을 요구하는 분야, 예를 들면 교직, 성직, 판매 특히 동정심을 필요로 하는 간호나 의료 분야에 적합하다',
#   '일이나 사람들에 대한 문제에 대하여 냉철한 입장을 취하기 어려워한다',
#   '반대 의견에 부딪혔을 때나 제 요구가 거절당했을 때 마음의 상처를 받는다',
#   '겉보기 특성 - 사회성이 풍부하며 정이 많고 사람들을 잘 다룬다',
#   '철저하게 현실주의적이지만 타인의 감정을 잘 배려하는 편이라 막상 타인이 듣기에 어려워하는 말은 보통 생략하는 편이다',
#   '몽상가스러운 NP 성향을 가진 사람과는 어느정도 거리를 유지한 상태로는 잘 지내나 너무 가까워지기 시작하면 어느새 마음속으로는 멀어지기도 한다',
#   'INTP,\xa0INTJ는 정반대다',
#   '하지만 정이 많고 배신을 하지 못하기 때문에 한 번 인간관계에서 큰 상처를 받으면 계속 추락하는 편에 속한다',
#   '그만큼 여리고 깊고 눈물이 많은 사람이 많다는 것이다',
#   '또한 사회의 현실에 적응도 잘 하는 유형인 만큼 평균 수입도 높은 편이다',
#   '정서 상 국가별로 다르긴 하지만  인구비율 순위에서 최상위권을 차지하는 빈도가 높은 등, MBTI 유형 중 매우 흔한 편에 속한다',
#   '주의 - 아래 항목은 다른 사람이 각 유형들을 보았을 때 일반적으로 느끼는 특성 위주로 서술되어 있다는 점을 감안할 것',
#   '신나고 재미있는 성격이다',
#   '모든 MBTI 유형 중 외향 성향이 ESFP와 함께 가장 강한 편이다',
#   '즐거움을 추구한다',
#   '스트레스를 받으면 누구를 만나야 한다',
#   '강의 때 고개를 제일 많이 끄덕여 강사를 즐겁게 한다',
#   '준비성이 철저하며, 참을성이 많고 타인을 잘 돕는다',
#   '남에게 동조하는 경향이 뛰어나며 사람들과의 상호 활동에서 기력이 생긴다',
#   '타인의 인정을 받는 것에 아주 민감하다',
#   '보수적이며, 좋은 음식을 좋아하고, 봉사를 좋아하며 재물을 모으는 것을 즐긴다',
#   'INTP 유형에 주로 많이 끌리며 매우 높은 관심과 애정을 가진 경우가 많다',
#   '외국 커뮤니티 설문조사에서 ESFJ가 좋아하는 유형 1위가 INTP로 투표되었다',
#   '자신이 존경하는 사람이나 물건을 이상화하는 경향이 있다',
#   '집단의 일이나 목적을 개인의 것보다 앞세운다',
#   '주변 사람들에게 애정을 쏟으며 그들에게 선물하는 것을 좋아한다',
#   '조화와 균형을 중요시한다',
#   '싫은 소리하기 싫어한다',
#   '사람들 사이에서 중재자 역할을 잘한다',
#   '리액션이 좋은 편이다',
#   '1대 1보다는 다수 속에 있어야 좋다',
#   '아무 생각 없이 멍 때리기를 잘한다',
#   '한 번 생활습관이나 버릇을 들이면 잘 못 바꾼다',
#   '생각보다 굉장히 철저하고 현실주의적이다',
#   '하지만 남들에게 싫은 소리를 잘 안 하고 대부분 맞춰주기 때문에 겉으로는 티가 나지 않을 수 있다',
#   '화가나도 웬만하면 묵묵히 참아주는 편이다',
#   '예의 없는 사람, 남들 무시하는 사람을 굉장히 싫어한다',
#   '뉴스를 안 보더라도 가십거리가 될 만한 것은 챙겨둔다',
#   '남들 챙기는 것을 좋아한다',
#   '좋아하는 편에 속하지만 챙겨야 하는 책임감 때문에 어쩔 수 없이 챙길 때도 많다',
#   '진지한 이야기보다 가벼운 이야기를 주로 한다',
#   '가벼운 이야기를 주로 하는것과는 다르게 사람 자체는 진지한 면이 있다',
#   '자기주장이 강하진 않다',
#   '남의 말에 ‘아 이건 아닌 것 같은데’하면서도 겉으로는 ‘맞아 맞아',
#   '’ 하는 유형',
#   '공감 능력이 좋다',
#   '진심으로 공감되지 않더라도 적당히 상대방의 기분에 맞춰주는 ‘가식적인’ 공감을 잘 해준다',
#   '윗 글처럼 처음에는 공감 되지 않던 타인의 주장을 들으며 가식적인 공감을 하다가도 “오 이 말도 일리가 있는데?” 하며 설득 당하는 경우도 잦다',
#   '싫어하는 사람에게도 겉으로 티 내지 않고 적당히 지낼 수 있다',
#   '전부 받아주다 보니 진짜 친구, 가짜 친구에 대해 구별 하는 법과 같은 인간관계 고민을 하는 경우도 있다',
#   '행동보다 말이 앞선다거나 뜬구름 잡는 소리를 하는것을 한심하게 생각하지만 겉으론 잘 받아준다',
#   '역지사지를 잘한다',
#   "타인을 진심으로 이해하기 힘들 경우 '그럴 수 있지' 라는 마음으로 넘어갈 가능성이 크다",
#   '무례하거나 융통성 없이 사사건건 따지려 드는 사람을 피곤하게 여긴다',
#   '사회성 없는 사람을 싫어한다',
#   '기본적으로 친절하다',
#   '사회생활을 잘하는 유형',
#   '거짓말을 잘 안 한다',
#   '솔직한 편이다',
#   '현실주의자',
#   '관심 있는 것에 기억력이 굉장히 좋다',
#   '한번 좋아하면 혼신을 다한다',
#   '친구들이 두루두루 많은 편이다',
#   '엄청 생각한다',
#   '말 한 마디에도 머리 굴린다',
#   '말을 조심히 하는 편에 속한다세상 물정에 밝다',
#   '옳고 그름을 날카롭게 구분한다',
#   '하지만 주위 분위기를 살피며 그에 따라 행동한다',
#   '눈치가 굉장히 빠른 편이다',
#   '동정심이 강하고 다 같이 사이좋게 지내는 것을 추구하기 때문에 약자를 잘 도와준다',
#   '한 번 깊은 관계를 맺은 사람들은 절대 배신하지 않는다',
#   '한 번 아니면 절대 아니다',
#   '돈보다는 명예를 추구하는 편이다',
#   '예의가 바르고 친절해 어느 곳에서도 빠르게 적응하는 편이다',
#   '참을성이 있다',
#   '자연스럽게 분위기를 주도하거나 리더 역할을 맡는 경우가 많다',
#   '승부욕이 생기면 주체가 안된다',
#   '변치 않는다',
#   '한번 시작하면 끝을 본다',
#   '자존감이 높은 편이다',
#   '그러나 딱히 티를 내지는 않는다',
#   '자신이 옳다 생각되는 일들에 보수적이다',
#   '이성을 볼 때도 첫 눈에 반해서 좋다기 보다는 그 사람이 어떤 사람인지 철저하게 알아보고 괜찮은 사람이다 생각되면 좋아한다',
#   '그래서 그런지 엄청 잘생기고 예쁜 것을 원하지는 않지만 어디 하나 빠지지 않는 상대를 원한다',
#   '완벽주의 기질이 약간 있다',
#   '남들을 잘 챙기고 부탁에 거절을 잘 안 하는 것도 맞지만 이렇게 하면서 자신의 이득도 잘 챙긴다',
#   '자기 이야기를 많이 하고 잘 한게 있으면 동네방네 떠들고 다니지만 분위기를 띄우고 재밌게 만들고 싶어서 말하는 편이고 진짜 크거나 중요한 일은 그 누구에게도 절대 말 하지 않는다',
#   '대부분은 입이 무겁다',
#   '긍정적이고 낙천적인 편이다',
#   '지금 자신의 위치와 생활에 만족하면서 살아간다',
#   '정이 굉장히 많다',
#   '그래서 그런지 주변 사람들 대부분을 굉장히 긍정적으로 평가하고 자신을 배신했거나 싸운 사람들도 그럴 만한 이유가 있었겠지 하면서 이해하는 편이다',
#   "이 유형 사람들이 '누구의 이런 면이 별로야",
#   "'  '이렇게 행동했으면 좋겠어",
#   "' 식의 어투가 아닌 '나 얘 진짜 싫어",
#   "'라고 확실하게 말했다면 그 사람은 정말 싫은거다",
#   '사람을 잘 싫어하지 않는데, 이 유형의 사람이 누군가를 싫어한다면 그 사람은 이미 모두가 싫어하는 사람이다',
#   '말이 많고 말도 잘 한다',
#   '면접과 같은 상황들에 강하다',
#   '사람들 이름과 얼굴을 잘 기억하고 잘 구분한다',
#   '알고 보면 입이 굉장히 무거운 유형 중 하나이다',
#   '책임감 있고 성실해 학창 시절 큰 문제 없이 잘 지내는 편이다',
#   '게으른 천재 유형인 INTP와 반대로 노력하는 범재 유형이 많으며 교사들이 좋아하는 학생 유형 중 하나이다',
#   '이 유형의 사람들은 즉흥적으로 한 행동은 후회하는 경우가 많다',
#   '유튜브를 보고 헬스장을 끊거나 새해라고 금주를 다짐하면 3일 이내에 실패함',
#   '철저히 계획 후에 행동하는 것이 더 동기부여 되는 유형낯을 가리지는 않지만 확실히 친해지기 전까지는 자신을 다 보여주지 않는 면이 있다',
#   '오지랖이 매우 넓은 편으로 ISTP, ISFP 등 개인적인 성향이 강한 유형은 ESFJ가 때로 부담스러울 수 있다',
#   '굉장히 사교적인 타입이지만 조용하다고 평가 받을수도 있다',
#   '하지만 조용하다는 평가를 받는 것은 매우 드문 일',
#   '본인은 맞춤법이나 띄어쓰기를 잘 지키려고 노력하지만, 남의 맞춤법 실수를 지적하지는 않는다',
#   '다만, 상대가 먼저 물어볼 경우에는 본인이 알고 있는 범위 내에서 최선을 다해 설명한다',
#   '꾸미기를 좋아한다',
#   '제이홉  출처혜리 출처박보검 출처황광희 출처규현  출처려욱  출처피오 출처앤디  출처서은광    출처서동성   민현   김도연  출처유선호 출처효정   이대휘  출처김동현  출처박초롱  출처김남주  출처정동원  출처리노, 승민, 아이엔   출처시온   다영, 여름   출처노지선  출처은채  출처박혜원   우영, 성화, 종호   출처효진  출처Love, 유정, Mill, 나인   출처정훈  출처채정, 가린   출처VAV BM  출처장대현 출처김준서 강석화 출처문호준  출처김환  오진승  출처춈미    출처황민경 출처서민재 출처동명  출처고은 이근 출처이이경 출처'],
#  'ENFJ': ['MBTI와 16Personalities 성격 유형 중 ENFJ 유형을 설명하는 문서',
#   '정의로운 사회운동가 / 언변능숙형',
#   '따뜻하고 적극적이며 책임감이 강하고 사교성이 풍부하고 동정심이 많다',
#   '상당히 이타적이고 민첩하고 인화를 중요시하고 참을성이 많다',
#   '다른 사람들의 생각이나 의견에 진지한 관심을 가지고 공동선을 위하여 다른 사람의 의견에 대체로 동의한다',
#   '현재보다는 미래의 가능성을 추구하며 편안하고 능란하게 계획을 제시하고 집단을 이끌어 가는 능력이 있다',
#   '때로 다른 사람들의 좋은 점을 지나치게 이상화하고 맹목적 충성을 보이는 경향이 있으며 다른 사람들에 대해서도 자기와 같을 것이라고 생각하는 경향이 있다',
#   'INFJ와 마찬가지로 보기 드문 유형으로, 전 세계 인구의 대략 1%가 이 유형에 속해있다고 한다',
#   '특히 이 유형을 가진 남성은 인구의 0',
#   '5% 미만으로 매우 드물다',
#   '연예인 중에서는 약 10% 정도로 상당히 흔하다',
#   '겉보기 특성 - 모임을 좋아하며 대화를 적극적으로 이끌어 나가는 면에서는 ENTJ와 다소 비슷하다',
#   '하지만 T성향과는 달리 F성향이 있어 타인의 반응에 대해서 더 예민하고, 말을 할때도 다른 사람한테 어려움이 될수 있는 말은 꺼내지 않는다',
#   '사실 모든 성격 유형 중 상대방에게 가장 부드럽게 말을 잘 하는 성격이다',
#   '주의 - 아래 항목은 다른 사람이 각 유형들을 보았을 때 일반적으로 느끼는 특성 위주로 서술되어 있다는 점을 감안할 것',
#   '그 외 특징들INFJ와 마찬가지로 가장 드문 MBTI 유형으로 인구의 1%가 채 되지 않는다',
#   '국내에서 가장 적은 유형이다',
#   '마음이 약하고 남의 의견에 동화를 잘하는 편이다',
#   '사람을 좋아하고 남에게 잘 맞춘다',
#   '말로 표현을 잘하고 생각이나 마음을 잘 연다',
#   '적극적이고 추진력이 강하다',
#   '일의 결과보다는 사람과의 인화를 더 중요시하는 편이다',
#   '사전 계획을 세우고 그에 따라 행하고자 한다',
#   '화가 나면 겉으로 표현하지 않고 묵묵히 참아낸다',
#   '정말 감정적으로 화를 냈다면 정말 누구든지 화를 낼 수준의 도 넘는 행동을 했다는 뜻',
#   '걱정이 매우 많으나 티를 잘 내지 않는다',
#   '타인에게 무척 사교적이지만 집에 있는 아이들에게는 안 그럴 수 있다',
#   '상처를 매우 잘 받고, 오랜 시간 가슴 아파한다',
#   '현실보다는 더 나은 삶 이상을 추구한다',
#   '맺고 끊는 것이 분명하지 못하다',
#   '그러나 자신에게 정이 없는 사람에게는 맺고 끊음이 분명하다',
#   '정, 눈물, 동정심이 많다',
#   '특히 정이 너무 많아서 가끔은 문제다',
#   '상대방의 말, 특히 비판에 민감하다',
#   '사람다움을 섬기기 위해서 또는 세계 평화를 위해서 등의 이유로 세상을 살아간다',
#   '갈등을 싫어한다',
#   '호기심이 많아 어떤 일이든지 직접 해봐야 직성이 풀린다',
#   '꿈이 여러 개인 경우가 많다',
#   '더 나은 세상을 만들기 위해 앞장서서 세상을 이끄는 것을 좋아한다',
#   '어떤 일이든지 비판적인 시각보다는 긍정적으로 보려는 시각이 강하다',
#   '자기관리에 철저하다',
#   '사람에 대해 맹목적 이상화 경향이 있다',
#   '타인에게는 관대하지만 본인에게는 매우 엄격하다',
#   '타인에게 인정과 칭찬을 받는 일에서 열중할 수 있다',
#   '사람을 위해 봉사하는 분야에 능력이 있다',
#   '정의로운 편이라 누가 억울해 하거나 약한 사람이 당하는 것을 못 참는다',
#   '사람과 사람을 잘 엮는다',
#   '감정의 기복이 심하다',
#   '거절을 잘 못하는 편이고 상대방을 지나치게 배려하거나 타인의 필요 를 지나치게 생각한다',
#   '모든 사람에게 사랑받고 싶어한다',
#   '본인이 어려움에 처했을 때, 도움을 요청하지 못하는 경우가 많다',
#   '본인이 사랑하는 사람에게 짐을 지우기를 싫어하기 때문이다',
#   '다른 사람들과 별 어려움 없이 잘 어울리며, 특히 사람들과 직접 얼굴을 보고 의사소통하는 것을 좋아한다',
#   '타인의 문제를 본인의 문제처럼 여기고 지나치게 관여하는 경우가 많다',
#   '남이 나서지 않은 일을 도맡아서 하려고 한다',
#   '오지랖이 넓은 편이다',
#   '무리에 속해 있는 것을 좋아하나 마이웨이 기질이 있다',
#   '타인의 성장을 돕고 옆에서 영향을 미칠 때 보람을 느낀다',
#   '임기응변이 능하다',
#   '타인이 이해하지 못하는 말을 할 때가 많다',
#   '24시간 7일동안 골든리트리버와 같은 체력을 보유하고 있다',
#   '기본적으로 사람을 좋아하고, 좋아하는 사람들에게 한 없이 퍼주는데, 이들에게 배신을 당하면 정신적인 타격이 크다',
#   'ENFJ 마이너 갤러리',
#   '강다니엘 출처강호이 출처김동빈  김동현 출처김동현   김민경 출처김연경   출처김인성 김원중 출처김재중 김재현    출처김재환  출처  김민서   출처니키 성수커플-성현님   출처노잼봇    출처디노 , 민규 , 조슈아    출처리아 , 유나    출처마크 테토   출처레이븐 문정희 출처미미미누    출처민니 아이들, 우기 아이들민혁  출처박미선   출처박종윤  방찬    출처밴쯔 출처범규   벤 애플렉     출처비범   성진    출처숀 코너리     출처소연   출처송윤형    출처수아 , 유현   출처 수현   수호 , 찬열    출처승희  출처 에릭 , 현재    출처예린 , 유주    출처오마르의 삶    출처오왼, MKIT RAIN 소속의 래퍼오정연 출처오프라 윈프리   출처왕심린   출처용승    출처 우감독    출처우도환유라    출처유리   유회승    출처윤시윤 출처 윤호    출처은서    출처이런    출처 이사배   출처이상민   출처이준수 이진솔   출처이진혁    출처이찬원   출처이채연     인성    출처임시완   출처임현주    잭슨    출처저스디스 인디고 뮤직 소속의 래퍼정승제    출처존 쿠삭     출처지민    출처켄    출처켄타    출처콜드   출처하린 , CyA 출처호연    출처희건TV    출처Jun',
#   'K    출처MINIMONSTER   RAVN 출처러셀 토비 출처이승재 임세준 허찬 임라라   출처'],
#  'ENTJ': ['MBTI와 16Personalities 성격 유형 중 ENTJ 유형을 설명하는 문서',
#   '대담한 통솔자지도자형',
#   '열성이 많고 솔직하고 단호하고 지도력과 통솔력이 있다',
#   '활동적이고 솔직하며, 결정력과 통솔력이 있고, 장기적 계획과 거시적 안목을 선호한다',
#   '지식에 대한 욕구와 관심이 많으며 특히 지적인 자극을 주는 새로운 아이디어에 높은 관심을 가졌다',
#   '일 처리에 있어 사전준비를 철저히 하며 논리 분석적으로 계획하고 조직하여 체계적으로 추진해 나가는 형이다',
#   '다른 사람의 의견에 귀를 기울일 필요가 있으며, 자신과 타인의 감정에 충실할 필요가 있다',
#   '겉보기 특성 - 사교활동에 매우 적극적이며 본인이 직접 모임을 주도하고 적극적으로 대화의 주도권을 이끌어 나가는 힘이 있는 성격이다',
#   "이것저것 논리적으로 계산을 하는데도 능숙해서 한마디로 가장 '똑'소리나는 느낌이 나는 성격의 대표주자이다",
#   '당연하게도 사회적으로 가장 성공하는 성격 유형이기도 하다',
#   '수는 적지만  영향력은 상당히 큰 편',
#   '주로 기업가, 사무관, 정치가, 전문직 직군에 많이 분포한다',
#   '활기찬 성격에 사교활동을 잘하고, 어려운 도전을 마다하지 않고 즐기며, 일과 친하다보니 성실한 경우가 많은데다가 논리정연하게 따지기를 좋아한다',
#   '통계를 보면 E 유형  중에서는 평균 지능도 ENTP 다음으로 높으며 16유형 중 상위권이다',
#   '현대 사회에 살아남기 위한 성격적 기질은 거의 다 가졌다고 봐도 무방하니 아무래도 성공률이 높을 수밖에 없다',
#   '주의 - 아래 항목은 다른 사람이 각 유형들을 보았을 때 일반적으로 느끼는 특성 위주로 서술되어 있다는 점을 감안할 것',
#   '타고난 지도자형 조직적, 체계적, 계획적이다',
#   '일은 일대로 하고 욕은 욕대로 먹을 수 있다',
#   '너무 완벽을 추구하기 때문에 남이 비집고 들어갈 틈이 없다',
#   '상상을 많이 한다',
#   '대부분은 혼자 있는 것을 싫어하는 편이다',
#   '인간 교류를 할 때 감정 교류보단 아이디어를 나누고 협력해서 이루는 것을 좋아한다',
#   '고집이 센 것처럼 보이지만 내 생각이 잘못된 것이 확인되면 바로 수긍한다',
#   '호기심이 많다',
#   '지적 욕구가 강하다',
#   '감정 표현이 솔직해서 타인이 상처를 받을 수 있다',
#   '사람보다 일을 중시한다',
#   '가까운 사람에게 헌신적이지만 멀어지면 뒤돌아보지 않는다',
#   '가장 좋아하는 사람은 일 잘하는 사람',
#   '항상 계획을 하고 실행한다',
#   '일상적인 반복되는 일을 싫어한다',
#   '변화 있는 생활을 즐긴다',
#   '어려운 일을 만나도 자극이 되어 쉽게 처리한다',
#   '지적 능력 향상에 노력하고자 한다',
#   '권위적이지 않고 아랫사람들하고 의논도 잘한다',
#   '오히려 부조리하고 비합리적인 것을 혐오한다',
#   '반면 자신이 아랫사람이 되는 걸 싫어한다',
#   '자기 주관이 가장 확고하기 때문에 꼰대들에게 가장 많이 저항하는 유형으로 알려져 있다',
#   '미래에 대한 꿈이 크다',
#   '솔직하고 결단력, 통솔력이 있으며 거시적 안목으로 일을 추진해 나간다',
#   '일이 틀어지느니 미운털 박히고 말 것이다',
#   '효율을 중요시한다',
#   'ENTJ = 사자',
#   '유노윤호  이특  출처Key  서현   지코 출처김병관  출처채인   티파니 영 출처 스윙스 출처도영 , 지훈     출처디투  출처베이비소울  출처 비토    출처신성록 출처심바 자와디 아샤    출처 이낙준  출처이수진  출처이승기 출처이재경  출처잠뜰  출처주학년   출처지식의 칼  현우진  출처 희진   최고기출처찬',
#   '전문 계열: 변호사, 외교관, 정치인, 장성급 장교사업 계열: CEO']}

# %%
okt.nouns('거절을 잘 못하는 편이고 상대방을 지나치게 배려하거나 타인의 필요를 지나치게 생각한다')
# Out:
# ['거절', '편이', '상대방', '타인', '필요', '생각']

# %%
tokens = okt.morphs('거절을 잘 못하는 편이고 상대방을 지나치게 배려하거나 타인의 필요를 지나치게 생각한다')
text = nltk.Text(tokens, name='NMSC')

# %%
text.collocations()

# %%
tokens
# Out:
# ['거절',
#  '을',
#  '잘',
#  '못',
#  '하는',
#  '편이',
#  '고',
#  '상대방',
#  '을',
#  '지나치게',
#  '배려하거나',
#  '타인',
#  '의',
#  '필요',
#  '를',
#  '지나치게',
#  '생각',
#  '한다']

# %%
def analyzer(data, target):
    noun_list = []
    target_data = data[target]
    
    except_item_list = ['출처', '것', '등', '이', '중', '때', '를', '그', '유형']
    
    for text in target_data:
        nouns = okt.nouns(text)
        for noun in nouns:
            if (noun not in except_item_list):
                noun_list.append(noun)
            
    return nltk.Text(noun_list, name='NMSC')

# %%
analyzer(data, 'INTJ').vocab().most_common(50)
# Out:
# [('사람', 25),
#  ('수', 16),
#  ('자기', 16),
#  ('상황', 15),
#  ('생각', 15),
#  ('편이', 14),
#  ('관계', 14),
#  ('자신', 11),
#  ('능력', 11),
#  ('자녀', 11),
#  ('일', 10),
#  ('속', 10),
#  ('위', 10),
#  ('사회', 10),
#  ('본인', 10),
#  ('합리', 9),
#  ('성향', 9),
#  ('때문', 9),
#  ('분야', 8),
#  ('필요', 8),
#  ('못', 7),
#  ('경우', 7),
#  ('감정', 7),
#  ('사고', 7),
#  ('가장', 7),
#  ('중시', 6),
#  ('의견', 6),
#  ('방식', 6),
#  ('자주', 6),
#  ('이상', 6),
#  ('지식', 6),
#  ('대한', 6),
#  ('효율', 6),
#  ('공부', 6),
#  ('성격', 6),
#  ('인간', 6),
#  ('계획', 6),
#  ('친구', 6),
#  ('더', 6),
#  ('비율', 6),
#  ('주의', 5),
#  ('이기', 5),
#  ('편', 5),
#  ('이해', 5),
#  ('가끔', 5),
#  ('현실', 5),
#  ('모든', 5),
#  ('지적', 5),
#  ('수도', 5),
#  ('단계', 5)]
